# %%
# Cell 1 — Install & verify required packages in the active Jupyter kernel
# %pip install --upgrade yfinance pandas openpyxl requests tqdm python-dateutil

# verify
import importlib
for pkg in ["yfinance", "pandas", "openpyxl", "requests", "tqdm", "dateutil"]:
    try:
        importlib.import_module(pkg)
        print(f"✅ {pkg} installed")
    except Exception as e:
        print(f"❌ {pkg} missing: {e}")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yfinance in c:\users\kiit\appdata\roaming\python\python313\site-packages (0.2.66)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (2.2.3)
# Collecting pandas
#   Downloading pandas-2.3.2-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: openpyxl in c:\programdata\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (2.32.3)
# Collecting requests
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (4.67.1)
# Requirement already satisfied: python-dateutil in c:\programdata\anaconda3\lib\site-packages (2.9.0.post0)
# Requirement already satisfied: numpy>=1.16.5 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (2.1.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\kiit\appdata\roaming\python\python313\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\kiit\appdata\roaming\python\python313\site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\kiit\appdata\roaming\python\python313\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (5.29.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\kiit\appdata\roaming\python\python313\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in c:\programdata\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests) (2025.4.26)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Downloading pandas-2.3.2-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 7.7 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/11.0 MB 4.1 MB/s eta 0:00:03
#    --------- ------------------------------ 2.6/11.0 MB 4.7 MB/s eta 0:00:02
#    -------------- ------------------------- 3.9/11.0 MB 5.0 MB/s eta 0:00:02
#    ------------------ --------------------- 5.0/11.0 MB 5.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.3/11.0 MB 5.2 MB/s eta 0:00:01
#    --------------------------- ------------ 7.6/11.0 MB 5.4 MB/s eta 0:00:01
#    ------------------------------- -------- 8.7/11.0 MB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 5.3 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Installing collected packages: requests, pandas
#
#    ---------------------------------------- 0/2 [requests]
#    ---------------------------------------- 0/2 [requests]
#    ---------------------------------------- 0/2 [requests]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    ---------------------------------------- 2/2 [pandas]
#
# Successfully installed pandas-2.3.2 requests-2.32.5
# Note: you may need to restart the kernel to use updated packages.
# ✅ yfinance installed
# ✅ pandas installed
# ✅ openpyxl installed
# ✅ requests installed
# ✅ tqdm installed
# ✅ dateutil installed

# %%
# Cell 2 — Configuration (edit only these paths if needed)
import os, sys, time, math, json
from pathlib import Path

# === Edit these paths to match your environment (use raw string or forward slashes) ===
INPUT_FILE = r"C:\Users\KIIT\Downloads\stock_list.txt"
OUT_BALANCE_XLSX = r"C:\Users\KIIT\Downloads\all_companies_balancesheet.xlsx"
OUT_OVERVIEW_XLSX = r"C:\Users\KIIT\Downloads\all_companies_overview.xlsx"
ERRORS_CSV = r"C:\Users\KIIT\Downloads\errors.csv"
MANUAL_MAP_CSV = r"C:\Users\KIIT\Downloads\manual_mapping_suggestions.csv"

# Processing config
THREADS = 6                # concurrency; decrease if you get throttled
REQUEST_RETRIES = 3        # attempts for network calls
BASE_SLEEP = 0.6           # base sleep between calls (seconds)
TIMEOUT = 15               # HTTP timeout
# Overview column order to match your earlier file
OVERVIEW_COLUMNS = ["Company", "Yahoo_Ticker", "Price", "Market_Cap", "Revenue", "Net_Profit", "PE_Ratio", "ROE", "Sector", "Industry"]
# don't change below
INPUT_FILE = str(Path(INPUT_FILE))
print("Config set. Input:", INPUT_FILE)
# Out:
# Config set. Input: C:\Users\KIIT\Downloads\stock_list.txt

# %%
# Cell 3 — Imports & helper utilities
import requests
import pandas as pd
import yfinance as yf
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm.notebook import tqdm
import re
from urllib.parse import quote_plus

# small helper: safe Excel sheet name
def safe_sheet_name(name: str) -> str:
    # remove forbidden characters and truncate to 31 chars
    name = re.sub(r'[:\\/?*\[\]]', '_', str(name))
    return name[:31]

# normalize raw ticker lines
def normalize_raw_line(line: str) -> str:
    if not line:
        return ""
    s = line.strip()
    # If file contains comma-separated or extra info, keep the first token
    s = s.split()[0]
    # remove common suffixes like _full
    if "_" in s:
        s = s.split("_")[0]
    return s.strip()

# HTTP wrapper with retries
def safe_get(url, headers=None, params=None, timeout=TIMEOUT, tries=REQUEST_RETRIES):
    last_exc = None
    for attempt in range(tries):
        try:
            r = requests.get(url, headers=headers, params=params, timeout=timeout)
            r.raise_for_status()
            return r
        except Exception as e:
            last_exc = e
            time.sleep(BASE_SLEEP * (2 ** attempt))
    raise last_exc

# %%
# Cell 4 — Yahoo search fallback function (find possible symbol matches)
def yahoo_search(query: str, limit:int=8):
    """
    Uses Yahoo's public search endpoint to find matching symbols.
    Returns a list of dicts containing keys like 'symbol','shortname','exch','type'
    """
    url = "https://query1.finance.yahoo.com/v1/finance/search"
    params = {"q": query, "quotesCount": limit, "newsCount": 0}
    try:
        r = safe_get(url, params=params)
        j = r.json()
        results = j.get("quotes", []) + j.get("news", [])
        candidates = []
        for item in j.get("quotes", []):
            # keep only equity / funds; we will filter later for .NS or NSE
            sym = item.get("symbol")
            name = item.get("shortname") or item.get("longname") or item.get("quoteType")
            exch = item.get("exchange")
            candidates.append({"symbol": sym, "name": name, "exchange": exch, "raw": item})
        return candidates
    except Exception:
        return []

# %%
# Cell 5 — Main fetch function per ticker (tries multiple resolution strategies)
def resolve_and_fetch(raw_ticker: str):
    """
    Attempt to get a working Yahoo ticker for an NSE stock and fetch its balance sheet and overview.
    Returns:
      - success (bool)
      - yahoo_symbol (str or None)
      - company_name (str or None)
      - balance_df (pd.DataFrame)  -> annual balance sheet transposed (Periods as rows)
      - overview_row (dict) matching OVERVIEW_COLUMNS
      - error_message (str or None)
    """
    rt = normalize_raw_line(raw_ticker)
    if not rt:
        return False, None, None, pd.DataFrame(), {}, "empty input"

    tried_symbols = []
    errors = []

    # candidate generation rules:
    candidates_to_try = []

    # 1) if looks like a Yahoo symbol already (contains .)
    if "." in rt:
        candidates_to_try.append(rt)
    # 2) direct with .NS suffix
    candidates_to_try.append(rt + ".NS")
    # 3) uppercase without .NS then with .NS
    t_up = re.sub(r'[^A-Za-z0-9&]', '', rt).upper()
    candidates_to_try.append(t_up + ".NS")
    # 4) if & in ticker or official name variants: try replacing & with AND and vice versa
    if "&" in t_up:
        candidates_to_try.append(t_up.replace("&","AND") + ".NS")
    if "AND" in t_up:
        candidates_to_try.append(t_up.replace("AND","&") + ".NS")
    # dedupe preserve order
    seen = set()
    candidates_to_try = [c for c in candidates_to_try if not (c in seen or seen.add(c))]

    # helper to attempt a single yahoo symbol
    def try_symbol(sym):
        try:
            tried_symbols.append(sym)
            t = yf.Ticker(sym)
            # attempt to fetch info (this triggers a network call inside yfinance)
            info = {}
            try:
                info = t.info or {}
            except Exception as e:
                # yfinance 404 or JSON parse issues
                info = {}
            # if info contains symbol or longName, treat as found
            if info and (info.get("symbol") or info.get("longName") or info.get("shortName")):
                # fetch balance sheet; prefer annual balance sheet
                try:
                    bal = t.balance_sheet
                    # yfinance returns DataFrame with columns = periods; convert to rows per period
                    if bal is not None and not bal.empty:
                        bal_df = bal.transpose().reset_index().rename(columns={"index":"Unnamed: 0"})
                    else:
                        bal_df = pd.DataFrame()
                    # construct overview row
                    row = {
                        "Company": info.get("longName") or info.get("shortName") or sym,
                        "Yahoo_Ticker": sym,
                        "Price": info.get("currentPrice") or info.get("previousClose"),
                        "Market_Cap": info.get("marketCap"),
                        "Revenue": info.get("totalRevenue") or info.get("trailingAnnualRevenue"),
                        "Net_Profit": info.get("netIncomeToCommon") or info.get("netIncome"),
                        "PE_Ratio": info.get("trailingPE") or info.get("forwardPE"),
                        "ROE": (info.get("returnOnEquity") * 100) if info.get("returnOnEquity") is not None and abs(info.get("returnOnEquity")) <=1 else info.get("returnOnEquity"),
                        "Sector": info.get("sector"),
                        "Industry": info.get("industry")
                    }
                    # ensure order
                    overview_row = {k: row.get(k) for k in OVERVIEW_COLUMNS}
                    return True, sym, row["Company"], bal_df, overview_row, None
                except Exception as e:
                    return False, None, None, pd.DataFrame(), {}, f"yfinance fetch error: {e}"
            else:
                return False, None, None, pd.DataFrame(), {}, f"yfinance returned no info for {sym}"
        except Exception as e:
            return False, None, None, pd.DataFrame(), {}, f"exception trying symbol {sym}: {e}"

    # 1. Try candidate symbols deterministically
    for sym in candidates_to_try:
        ok, sym_found, comp_name, bal_df, overview_row, err = try_symbol(sym)
        if ok:
            return True, sym_found, comp_name, bal_df, overview_row, None
        else:
            errors.append((sym, err))

    # 2. If deterministic tries failed, attempt a Yahoo Search by using the raw token or a cleaned version
    search_queries = [rt, t_up, re.sub(r'\d+$','', t_up)]  # try raw, uppercase, remove trailing digits
    for q in search_queries:
        if not q:
            continue
        candidates = yahoo_search(q)
        # prefer NSE / .NS candidates if present in results
        # candidates are dicts: {'symbol':..., 'name':..., 'exchange':...}
        prioritized = []
        for c in candidates:
            sym = c.get("symbol")
            if not sym:
                continue
            # prefer symbols that end with .NS or mention NSE / India in exchange
            if sym.endswith(".NS") or (c.get("exchange") and "NSE" in str(c.get("exchange")).upper()):
                prioritized.insert(0, sym)  # high priority
            else:
                prioritized.append(sym)
        # try found prioritized symbols
        for sym in prioritized:
            ok, sym_found, comp_name, bal_df, overview_row, err = try_symbol(sym)
            if ok:
                return True, sym_found, comp_name, bal_df, overview_row, None
            else:
                errors.append((sym, err))

    # 3. If still not found, return failure with suggestions (candidates tried and last errors)
    suggestion_symbols = [c for c,_ in errors][:10]
    msg = f"Not resolved. Tried: {tried_symbols[:10]}. Suggestions from search: {suggestion_symbols}."
    return False, None, None, pd.DataFrame(), {}, msg

# %%
# Cell 6 — Read input tickers and run batch with concurrency; store intermediate results in memory
# NOTE: you can run this cell and it will process all tickers. For large lists it takes time.
with open(INPUT_FILE, "r", encoding="utf-8") as f:
    raw_lines = [ln.strip() for ln in f if ln.strip()]

print(f"Loaded {len(raw_lines)} tickers to process.")

successful = []
overview_rows = []
balances_map = {}   # key -> (symbol, company_name, dataframe)
errors = []

# We'll use a thread pool and tqdm progress bar
with ThreadPoolExecutor(max_workers=THREADS) as ex:
    future_to_raw = {ex.submit(resolve_and_fetch, rl): rl for rl in raw_lines}
    for fut in tqdm(as_completed(future_to_raw), total=len(future_to_raw), desc="Overall progress"):
        raw = future_to_raw[fut]
        try:
            ok, symbol, company_name, bal_df, overview_row, err = fut.result()
            if ok:
                successful.append((raw, symbol))
                # ensure sheet-safe company label
                sheet_label = f"{symbol}__{company_name}" if company_name else symbol
                sheet_label = safe_sheet_name(sheet_label)
                balances_map[sheet_label] = (symbol, company_name, bal_df)
                overview_rows.append(overview_row)
                print(f"[OK] {raw} -> {symbol} ({company_name})")
            else:
                errors.append((raw, err))
                print(f"[FAIL] {raw} -> {err}")
        except Exception as e:
            errors.append((raw, str(e)))
            print(f"[EXC] {raw} -> {e}")

print(f"Processing finished. Success: {len(successful)}, Failures: {len(errors)}")
# Out:
# Loaded 2135 tickers to process.
# Overall progress:   0%|          | 0/2135 [00:00<?, ?it/s]
# [OK] 20MICRONS_full -> 20MICRONS.NS (20 Microns Limited)
# [OK] 3MINDIA_full -> 3MINDIA.NS (3M India Limited)
# [OK] 21STCENMGM_full -> 21STCENMGM.NS (Twentyfirst Century Management Services Limited)
# [OK] 3PLAND_full -> 3PLAND.NS (3P Land Holdings Ltd)
# [OK] 5PAISA_full -> 5PAISA.NS (5paisa Capital Limited)
# [OK] 360ONE_full -> 360ONE.NS (360 One Wam Limited)
# [OK] 63MOONS_full -> 63MOONS.NS (63 moons technologies limited)
# [OK] AADHARHFC_full -> AADHARHFC.NS (AADHAR HOUSING FINANCE L)
# [OK] AAKASH_full -> AAKASH.NS (Aakash Exploration Services Limited)
# [OK] A2ZINFRA_full -> A2ZINFRA.NS (A2Z Infra Engineering Limited)
# [OK] AAATECH_full -> AAATECH.NS (AAA Technologies Limited)
# [OK] AARON_full -> AARON.NS (Aaron Industries Limited)
# [OK] AAREYDRUGS_full -> AAREYDRUGS.NS (Aarey Drugs & Pharmaceuticals Limited)
# [OK] AARTIDRUGS_full -> AARTIDRUGS.NS (Aarti Drugs Limited)
# [OK] AARTIIND_full -> AARTIIND.NS (Aarti Industries Limited)
# [OK] AARTIPHARM_full -> AARTIPHARM.NS (Aarti Pharmalabs Limited)
# [OK] AARTECH_full -> AARTECH.NS (Aartech Solonics Limited)
# [OK] AARTISURF_full -> AARTISURF.NS (Aarti Surfactants Limited)
# [OK] AAVAS_full -> AAVAS.NS (Aavas Financiers Limited)
# [OK] ABBOTINDIA_full -> ABBOTINDIA.NS (Abbott India Limited)
# [OK] AARVI_full -> AARVI.NS (Aarvi Encon Limited)
# [OK] AARVEEDEN_full -> AARVEEDEN.NS (Varvee Global Limited)
# [OK] ABAN_full -> ABAN.NS (Aban Offshore Limited)
# [OK] ABFRL_full -> ABFRL.NS (Aditya Birla Fashion and Retail Limited)
# [OK] ABB_full -> ABB.NS (ABB India Limited)
# [OK] ABINFRA_full -> ABINFRA.NS (A B INFRABUILD LIMITED)
# [OK] ABCAPITAL_full -> ABCAPITAL.NS (Aditya Birla Capital Limited)
# [OK] ABDL_full -> ABDL.NS (ALLIED BLEND N DISTILS L)
# [OK] ABMINTLLTD_full -> ABMINTLLTD.NS (ABM International Limited)
# [OK] ABLBL_full -> ABLBL.NS (ADITYA BIRLA LIFES BRAN L)
# [OK] ABREL_full -> ABREL.NS (Aditya Birla Real Estate Limited)
# [OK] ACCURACY_full -> ACCURACY.NS (Accuracy Shipping Limited)
# [OK] ABSLAMC_full -> ABSLAMC.NS (Aditya Birla Sun Life AMC Limited)
# [OK] ACCELYA_full -> ACCELYA.NS (Accelya Solutions India Limited)
# [OK] ACEINTEG_full -> ACEINTEG.NS (Ace Integrated Solutions Limited)
# [OK] ACE_full -> ACE.NS (Action Construction Equipment Limited)
# [OK] ACI_full -> ACI.NS (Archean Chemical Industries Limited)
# [OK] ACC_full -> ACC.NS (ACC Limited)
# [OK] ACL_full -> ACL.NS (Andhra Cements Limited)
# [OK] ACLGATI_full -> ACLGATI.NS (Allcargo Gati Limited)
# [OK] ACUTAAS_full -> ACUTAAS.NS (Acutaas Chemicals Limited)
# [OK] ADANIENSOL_full -> ADANIENSOL.NS (Adani Energy Solutions Limited)
# [OK] ADANIENT_full -> ADANIENT.NS (Adani Enterprises Limited)
# [OK] ACMESOLAR_full -> ACMESOLAR.NS (ACME SOLAR HOLDINGS LTD)
# [OK] ADANIGREEN_full -> ADANIGREEN.NS (Adani Green Energy Limited)
# [OK] ADL_full -> ADL.NS (Archidply Decor Limited)
# [OK] ADANIPORTS_full -> ADANIPORTS.NS (Adani Ports and Special Economic Zone Limited)
# [OK] ADFFOODS_full -> ADFFOODS.NS (ADF Foods Limited)
# [OK] ADOR_full -> ADOR.NS (Ador Welding Limited)
# [OK] ADANIPOWER_full -> ADANIPOWER.NS (Adani Power Limited)
# [OK] ADVANIHOTR_full -> ADVANIHOTR.NS (Advani Hotels & Resorts (India) Limited)
# [OK] ADSL_full -> ADSL.NS (Allied Digital Services Limited)
# [OK] ADROITINFO_full -> ADROITINFO.NS (Adroit Infotech Limited)
# [OK] ADVENZYMES_full -> ADVENZYMES.NS (Advanced Enzyme Technologies Limited)
# [OK] AEGISVOPAK_full -> AEGISVOPAK.NS (AEGIS VOPAK TERMINALS LTD)
# [OK] AEROFLEX_full -> AEROFLEX.NS (Aeroflex Industries Limited)
# [OK] AEROENTER_full -> AEROENTER.NS (Aeroflex Enterprises Limited)
# [OK] AEGISLOG_full -> AEGISLOG.NS (AEGIS LOGISTICS LIMITED)
# [OK] AFCONS_full -> AFCONS.NS (AFCONS INFRASTRUCTURE LTD)
# [OK] AFFLE_full -> AFFLE.NS (Affle 3i Limited)
# [OK] AETHER_full -> AETHER.NS (Aether Industries Limited)
# [OK] AFFORDABLE_full -> AFFORDABLE.NS (Affordable Robotic & Automation Limited)
# [OK] AGARWALEYE_full -> AGARWALEYE.NS (DR AGARWALS HEALTH CARE L)
# [OK] AFSL_full -> AFSL.NS (Abans Financial Services Limited)
# [OK] AGARIND_full -> AGARIND.NS (Agarwal Industrial Corporation Limited)
# [OK] AGIIL_full -> AGIIL.NS (AGI Infra Limited)
# [OK] AGRITECH_full -> AGRITECH.NS (Agri-tech (India) Limited)
# [OK] AGROPHOS_full -> AGROPHOS.NS (Agro Phos (India) Limited)
# [OK] AGSTRA_full -> AGSTRA.NS (AGS Transact Technologies Limited)
# [OK] AHLADA_full -> AHLADA.NS (Ahlada Engineers Limited)
# [OK] AGI_full -> AGI.NS (AGI Greenpac Limited)
# [OK] AHLUCONT_full -> AHLUCONT.NS (Ahluwalia Contracts (India) Limited)
# [OK] AIAENG_full -> AIAENG.NS (AIA Engineering Limited)
# [OK] AHLEAST_full -> AHLEAST.NS (Asian Hotels (East) Limited)
# [OK] AFIL_full -> AFIL.NS (AKME FINTRADE (INDIA) LTD)
# [OK] AIRAN_full -> AIRAN.NS (Airan Limited)
# [OK] AIROLAM_full -> AIROLAM.NS (Airo Lam Limited)
# [OK] AIIL_full -> AIIL.NS (Authum Investment & Infrastructure Limited)
# [OK] AJAXENGG_full -> AJAXENGG.NS (AJAX ENGINEERING LIMITED)
# [OK] AJMERA_full -> AJMERA.NS (Ajmera Realty & Infra India Limited)
# [OK] AJANTPHARM_full -> AJANTPHARM.NS (Ajanta Pharma Limited)
# [OK] AKASH_full -> AKASH.NS (Akash Infra-Projects Limited)
# [OK] AJOONI_full -> AJOONI.NS (Ajooni Biotech Limited)
# [OK] AKI_full -> AKI.NS (AKI India Limited)
# [OK] AKSHARCHEM_full -> AKSHARCHEM.NS (AksharChem (India) Limited)
# [OK] AKG_full -> AKG.NS (AKG Exim Limited)
# [OK] AKSHAR_full -> AKSHAR.NS (Akshar Spintex Limited)
# [OK] AKSHOPTFBR_full -> AKSHOPTFBR.NS (Aksh Optifibre Limited)
# [OK] AKUMS_full -> AKUMS.NS (AKUMS DRUGS AND PHARMA L)
# [OK] ALANKIT_full -> ALANKIT.NS (Alankit Limited)
# [OK] ALEMBICLTD_full -> ALEMBICLTD.NS (Alembic Limited)
# [OK] AKZOINDIA_full -> AKZOINDIA.NS (Akzo Nobel India Limited)
# [OK] ALBERTDAVD_full -> ALBERTDAVD.NS (Albert David Limited)
# [OK] ALICON_full -> ALICON.NS (Alicon Castalloy Limited)
# [OK] ALKEM_full -> ALKEM.NS (Alkem Laboratories Limited)
# [OK] ALLDIGI_full -> ALLDIGI.NS (Alldigi Tech Limited)
# [OK] ALKYLAMINE_full -> ALKYLAMINE.NS (Alkyl Amines Chemicals Limited)
# [OK] ALIVUS_full -> ALIVUS.NS (Alivus Life Sciences Limited)
# [OK] ALLCARGO_full -> ALLCARGO.NS (Allcargo Logistics Limited)
# [OK] ALKALI_full -> ALKALI.NS (Alkali Metals Limited)
# [OK] ALPHAGEO_full -> ALPHAGEO.NS (Alphageo (India) Limited)
# [OK] ALPA_full -> ALPA.NS (Alpa Laboratories Limited)
# [OK] ALMONDZ_full -> ALMONDZ.NS (Almondz Global Securities Limited)
# [OK] ALPSINDUS_full -> ALPSINDUS.NS (Alps Industries Limited)
# [OK] AMBICAAGAR_full -> AMBICAAGAR.NS (Ambica Agarbathies Aroma & Industries Limited)
# [OK] ALOKINDS_full -> ALOKINDS.NS (Alok Industries Limited)
# [OK] AMDIND_full -> AMDIND.NS (AMD Industries Limited)
# [OK] AMBUJACEM_full -> AMBUJACEM.NS (Ambuja Cements Limited)
# [OK] AMBIKCO_full -> AMBIKCO.NS (Ambika Cotton Mills Limited)
# [OK] AMBER_full -> AMBER.NS (Amber Enterprises India Limited)
# [OK] AMJLAND_full -> AMJLAND.NS (AMJ Land Holdings Limited)
# [OK] ANANDRATHI_full -> ANANDRATHI.NS (Anand Rathi Wealth Limited)
# [OK] AMRUTANJAN_full -> AMRUTANJAN.NS (Amrutanjan Health Care Limited)
# [OK] ANANTRAJ_full -> ANANTRAJ.NS (Anant Raj Limited)
# [OK] ANDHRSUGAR_full -> ANDHRSUGAR.NS (The Andhra Sugars Limited)
# [OK] AMNPLST_full -> AMNPLST.NS (Amines & Plasticizers Limited)
# [OK] ANGELONE_full -> ANGELONE.NS (Angel One Limited)
# [OK] ANDHRAPAP_full -> ANDHRAPAP.NS (Andhra Paper Limited)
# [OK] ANIKINDS_full -> ANIKINDS.NS (Anik Industries Limited)
# [OK] ANKITMETAL_full -> ANKITMETAL.NS (Ankit Metal & Power Limited)
# [OK] ANMOL_full -> ANMOL.NS (Anmol India Limited)
# [OK] ANTGRAPHIC_full -> ANTGRAPHIC.NS (Antarctica Limited)
# [OK] ANUHPHR_full -> ANUHPHR.NS (Anuh Pharma Limited)
# [OK] ANUP_full -> ANUP.NS (The Anup Engineering Limited)
# [OK] ANSALAPI_full -> ANSALAPI.NS (Ansal Properties & Infrastructure Limited)
# [OK] ANURAS_full -> ANURAS.NS (Anupam Rasayan India Ltd)
# [OK] APCL_full -> APCL.NS (Anjani Portland Cement Limited)
# [OK] ANTHEM_full -> ANTHEM.NS (ANTHEM BIOSCIENCES LTD)
# [OK] APARINDS_full -> APARINDS.NS (APAR Industries Limited)
# [OK] APCOTEXIND_full -> APCOTEXIND.NS (Apcotex Industries Limited)
# [OK] APEX_full -> APEX.NS (Apex Frozen Foods Limited)
# [OK] APLAPOLLO_full -> APLAPOLLO.NS (APL Apollo Tubes Limited)
# [OK] APLLTD_full -> APLLTD.NS (Alembic Pharmaceuticals Limited)
# [OK] APOLLOTYRE_full -> APOLLOTYRE.NS (Apollo Tyres Limited)
# [OK] APOLLOPIPE_full -> APOLLOPIPE.NS (Apollo Pipes Limited)
# [OK] APOLLOHOSP_full -> APOLLOHOSP.NS (Apollo Hospitals Enterprise Limited)
# [OK] APOLSINHOT_full -> APOLSINHOT.NS (Apollo Sindoori Hotels Limited)
# [OK] APOLLO_full -> APOLLO.NS (Apollo Micro Systems Limited)
# [OK] APTECHT_full -> APTECHT.NS (Aptech Limited)
# [OK] ARCHIDPLY_full -> ARCHIDPLY.NS (Archidply Industries Limited)
# [OK] APTUS_full -> APTUS.NS (Aptus Value Housing Finance India Limited)
# [OK] ARENTERP_full -> ARENTERP.NS (Rajdarshan Industries Limited)
# [OK] ARIHANTCAP_full -> ARIHANTCAP.NS (Arihant Capital Markets Limited)
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: AREM.NS"}}}
# [OK] ARIES_full -> ARIES.NS (Aries Agro Limited)
# [OK] ARCHIES_full -> ARCHIES.NS (Archies Limited)
# [OK] ARFIN_full -> ARFIN.NS (Arfin India Limited)
# [OK] ARIHANTSUP_full -> ARIHANTSUP.NS (Arihant Superstructures Limited)
# [OK] ARISINFRA_full -> ARISINFRA.NS (ARISINFRA SOLUTIONS LTD)
# [OK] ARKADE_full -> ARKADE.NS (ARKADE DEVELOPERS LIMITED)
# [OK] ARMANFIN_full -> ARMANFIN.NS (Arman Financial Services Limited)
# [OK] ARROWGREEN_full -> ARROWGREEN.NS (Arrow Greentech Limited)
# [OK] ARSSINFRA_full -> ARSSINFRA.NS (ARSS Infrastructure Projects Limited)
# [OK] AROGRANITE_full -> AROGRANITE.NS (Aro Granite Industries Limited)
# [OK] ARVEE_full -> ARVEE.NS (Arvee Laboratories (India) Ltd.)
# [OK] ARTNIRMAN_full -> ARTNIRMAN.NS (Art Nirman Limited)
# [OK] ARTEMISMED_full -> ARTEMISMED.NS (Artemis Medicare Services Limited)
# [OK] ARVSMART_full -> ARVSMART.NS (Arvind SmartSpaces Limited)
# [OK] ARVIND_full -> ARVIND.NS (Arvind Limited)
# [OK] ASAHIINDIA_full -> ASAHIINDIA.NS (Asahi India Glass Limited)
# [OK] ASAHISONG_full -> ASAHISONG.NS (Asahi Songwon Colors Limited)
# [OK] ARVINDFASN_full -> ARVINDFASN.NS (Arvind Fashions Limited)
# [OK] ASALCBR_full -> ASALCBR.NS (Associated Alcohols & Breweries Limited)
# [OK] ASAL_full -> ASAL.NS (Automotive Stampings and Assemblies Limited)
# [OK] ASHAPURMIN_full -> ASHAPURMIN.NS (Ashapura Minechem Limited)
# [OK] ASHIANA_full -> ASHIANA.NS (Ashiana Housing Limited)
# [OK] ASHIMASYN_full -> ASHIMASYN.NS (Ashima Limited)
# [OK] ASIANHOTNR_full -> ASIANHOTNR.NS (Asian Hotels (North) Limited)
# [OK] ASHOKLEY_full -> ASHOKLEY.NS (Ashok Leyland Limited)
# [OK] ASHOKAMET_full -> ASHOKAMET.NS (Ashoka Metcast Limited)
# [OK] ASHOKA_full -> ASHOKA.NS (Ashoka Buildcon Limited)
# [OK] ASIANENE_full -> ASIANENE.NS (Asian Energy Services Limited)
# [OK] ASMS_full -> ASMS.NS (Bartronics India Limited)
# [OK] ASIANPAINT_full -> ASIANPAINT.NS (Asian Paints Limited)
# [OK] ASIANTILES_full -> ASIANTILES.NS (Asian Granito India Limited)
# [OK] ASKAUTOLTD_full -> ASKAUTOLTD.NS (ASK AUTOMOTIVE LIMITED)
# [OK] ASPINWALL_full -> ASPINWALL.NS (Aspinwall and Company Limited)
# [OK] ASTERDM_full -> ASTERDM.NS (Aster DM Healthcare Limited)
# [OK] ASTEC_full -> ASTEC.NS (Astec LifeSciences Limited)
# [OK] ASTRAL_full -> ASTRAL.NS (Astral Limited)
# [OK] ASTRON_full -> ASTRON.NS (Astron Paper & Board Mill Limited)
# [OK] ASTRAZEN_full -> ASTRAZEN.NS (AstraZeneca Pharma India Limited)
# [OK] ASTRAMICRO_full -> ASTRAMICRO.NS (Astra Microwave Products Limited)
# [OK] ATAM_full -> ATAM.NS (Atam Valves Limited)
# [OK] ATLANTAA_full -> ATLANTAA.NS (Atlantaa Limited)
# [OK] ATALREAL_full -> ATALREAL.NS (Atal Realtech Limited)
# [OK] ATGL_full -> ATGL.NS (Adani Total Gas Limited)
# [OK] ATHERENERG_full -> ATHERENERG.NS (Ather Energy Limited)
# [OK] ATL_full -> ATL.NS (Allcargo Terminals Limited)
# [OK] ATLASCYCLE_full -> ATLASCYCLE.NS (Atlas Cycles (Haryana) Limited)
# [OK] ATULAUTO_full -> ATULAUTO.NS (Atul Auto Limited)
# [OK] ATUL_full -> ATUL.NS (Atul Ltd)
# [OK] AUBANK_full -> AUBANK.NS (AU Small Finance Bank Limited)
# [OK] AURIONPRO_full -> AURIONPRO.NS (Aurionpro Solutions Limited)
# [OK] AUROPHARMA_full -> AUROPHARMA.NS (Aurobindo Pharma Limited)
# [OK] AURUM_full -> AURUM.NS (Aurum PropTech Limited)
# [OK] AVADHSUGAR_full -> AVADHSUGAR.NS (Avadh Sugar & Energy Limited)
# [OK] AVALON_full -> AVALON.NS (Avalon Technologies Limited)
# [OK] AUTOAXLES_full -> AUTOAXLES.NS (Automotive Axles Limited)
# [OK] AUTOIND_full -> AUTOIND.NS (Autoline Industries Limited)
# [OK] AUSOMENT_full -> AUSOMENT.NS (AuSom Enterprise Limited)
# [OK] AVANTEL_full -> AVANTEL.NS (Avantel Limited)
# [OK] AVONMORE_full -> AVONMORE.NS (Avonmore Capital & Management Services Limited)
# [OK] AVG_full -> AVG.NS (AVG Logistics Limited)
# [OK] AVANTIFEED_full -> AVANTIFEED.NS (Avanti Feeds Limited)
# [OK] AVROIND_full -> AVROIND.NS (Avro India Limited)
# [OK] AVL_full -> AVL.NS (Aditya Vision Limited)
# [OK] AWFIS_full -> AWFIS.NS (AWFIS SPACE SOLUTIONS LTD)
# [OK] AWL_full -> AWL.NS (AWL Agri Business Limited)
# [OK] AWHCL_full -> AWHCL.NS (Antony Waste Handling Cell Limited)
# [OK] AVTNPL_full -> AVTNPL.NS (AVT Natural Products Limited)
# [OK] AXISBANK_full -> AXISBANK.NS (Axis Bank Limited)
# [OK] AXISCADES_full -> AXISCADES.NS (AXISCADES Technologies Limited)
# [OK] AXITA_full -> AXITA.NS (Axita Cotton Limited)
# [OK] AZAD_full -> AZAD.NS (AZAD ENGINEERING LIMITED)
# [OK] AYMSYNTEX_full -> AYMSYNTEX.NS (AYM Syntex Limited)
# [OK] BAFNAPH_full -> BAFNAPH.NS (Bafna Pharmaceuticals Limited)
# [OK] BAGFILMS_full -> BAGFILMS.NS (B.A.G. Films and Media Limited)
# [OK] BAIDFIN_full -> BAIDFIN.NS (Baid Finserv Limited)
# [OK] BAJAJCON_full -> BAJAJCON.NS (Bajaj Consumer Care Limited)
# [OK] BAJAJ-AUTO_full -> BAJAJ-AUTO.NS (Bajaj Auto Limited)
# [OK] BAJAJELEC_full -> BAJAJELEC.NS (Bajaj Electricals Limited)
# [OK] BAJAJHLDNG_full -> BAJAJHLDNG.NS (Bajaj Holdings & Investment Limited)
# [OK] BAJAJFINSV_full -> BAJAJFINSV.NS (Bajaj Finserv Ltd.)
# [OK] BAJAJHFL_full -> BAJAJHFL.NS (BAJAJ HOUSING FINANCE LTD)
# [OK] BAJAJHCARE_full -> BAJAJHCARE.NS (Bajaj HealthCare Limited)
# [OK] BAJAJHIND_full -> BAJAJHIND.NS (Bajaj Hindusthan Sugar Limited)
# [FAIL] AREM_full -> Not resolved. Tried: ['AREM.NS']. Suggestions from search: ['AREM.NS'].
# [OK] BAJAJINDEF_full -> BAJAJINDEF.NS (INDEF MANUFACTURING LTD)
# [OK] BALAJEE_full -> BALAJEE.NS (SHREE TIRUPATI BALAJEE L)
# [OK] BAJEL_full -> BAJEL.NS (Bajel Projects Limited)
# [OK] BALAMINES_full -> BALAMINES.NS (Balaji Amines Limited)
# [OK] BALAJITELE_full -> BALAJITELE.NS (Balaji Telefilms Limited)
# [OK] BAJFINANCE_full -> BAJFINANCE.NS (Bajaj Finance Limited)
# [OK] BALAXI_full -> BALAXI.NS (Balaxi Pharmaceuticals Limited)
# [OK] BALKRISIND_full -> BALKRISIND.NS (Balkrishna Industries Limited)
# [OK] BALMLAWRIE_full -> BALMLAWRIE.NS (Balmer Lawrie & Co. Ltd.)
# [OK] BALKRISHNA_full -> BALKRISHNA.NS (Balkrishna Paper Mills Limited)
# [OK] BALUFORGE_full -> BALUFORGE.NS (Balu Forge Industries Limited)
# [OK] BALPHARMA_full -> BALPHARMA.NS (Bal Pharma Limited)
# [OK] BANARBEADS_full -> BANARBEADS.NS (Banaras Beads Limited)
# [OK] BALRAMCHIN_full -> BALRAMCHIN.NS (Balrampur Chini Mills Limited)
# [OK] BANARISUG_full -> BANARISUG.NS (Bannari Amman Sugars Limited)
# [OK] BANDHANBNK_full -> BANDHANBNK.NS (Bandhan Bank Limited)
# [OK] BANCOINDIA_full -> BANCOINDIA.NS (Banco Products (India) Limited)
# [OK] BANKA_full -> BANKA.NS (Banka BioLoo Limited)
# [OK] BANSALWIRE_full -> BANSALWIRE.NS (BANSAL WIRE INDUSTRIES L)
# [OK] BANKINDIA_full -> BANKINDIA.NS (Bank of India Limited)
# [OK] BANG_full -> BANG.NS (Bang Overseas Limited)
# [OK] BANKBARODA_full -> BANKBARODA.NS (Bank of Baroda Limited)
# [OK] BARBEQUE_full -> BARBEQUE.NS (United Foodbrands Limited)
# [OK] BANSWRAS_full -> BANSWRAS.NS (Banswara Syntex Limited)
# [OK] BASML_full -> BASML.NS (Bannari Amman Spinning Mills Ltd)
# [OK] BASF_full -> BASF.NS (BASF India Limited)
# [OK] BAYERCROP_full -> BAYERCROP.NS (Bayer CropScience Limited)
# [OK] BBOX_full -> BBOX.NS (Black Box Limited)
# [OK] BBL_full -> BBL.NS (Bharat Bijlee Limited)
# [OK] BATAINDIA_full -> BATAINDIA.NS (Bata India Limited)
# [OK] BBTCL_full -> BBTCL.NS (B&B Triplewall Containers Limited)
# [OK] BBTC_full -> BBTC.NS (The Bombay Burmah Trading Corporation Limited)
# [OK] BCG_full -> BCG.NS (Brightcom Group Limited)
# [OK] BECTORFOOD_full -> BECTORFOOD.NS (Mrs. Bectors Food Specialities Limited)
# [OK] BEARDSELL_full -> BEARDSELL.NS (Beardsell Limited)
# [OK] BCLIND_full -> BCLIND.NS (BCL Industries Limited)
# [OK] BCONCEPTS_full -> BCONCEPTS.NS (Brand Concepts Limited)
# [OK] BDL_full -> BDL.NS (Bharat Dynamics Limited)
# [OK] BEL_full -> BEL.NS (Bharat Electronics Limited)
# [OK] BELRISE_full -> BELRISE.NS (BELRISE INDUSTRIES LTD)
# [OK] BEPL_full -> BEPL.NS (Bhansali Engineering Polymers Limited)
# [OK] BEDMUTHA_full -> BEDMUTHA.NS (Bedmutha Industries Limited)
# [OK] BEML_full -> BEML.NS (BEML Limited)
# [OK] BESTAGRO_full -> BESTAGRO.NS (Best Agrolife Limited)
# [OK] BGRENERGY_full -> BGRENERGY.NS (BGR Energy Systems Limited)
# [OK] BERGEPAINT_full -> BERGEPAINT.NS (Berger Paints India Limited)
# [OK] BELLACASA_full -> BELLACASA.NS (Bella Casa Fashion & Retail Limited)
# [OK] BFUTILITIE_full -> BFUTILITIE.NS (BF Utilities Limited)
# [OK] BFINVEST_full -> BFINVEST.NS (BF Investment Limited)
# [OK] BHAGCHEM_full -> BHAGCHEM.NS (Bhagiradha Chemicals & Industries Limited)
# [OK] BHAGERIA_full -> BHAGERIA.NS (Bhageria Industries Limited)
# [OK] BHANDARI_full -> BHANDARI.NS (Bhandari Hosiery Exports Limited)
# [OK] BHARATRAS_full -> BHARATRAS.NS (Bharat Rasayan Limited)
# [OK] BHARATGEAR_full -> BHARATGEAR.NS (Bharat Gears Limited)
# [OK] BHARATFORG_full -> BHARATFORG.NS (Bharat Forge Limited)
# [OK] BHARATSE_full -> BHARATSE.NS (Bharat Seats Limited)
# [OK] BHEL_full -> BHEL.NS (Bharat Heavy Electricals Limited)
# [OK] BHARTIHEXA_full -> BHARTIHEXA.NS (BHARTI HEXACOM LIMITED)
# [OK] BHARATWIRE_full -> BHARATWIRE.NS (Bharat Wire Ropes Limited)
# [OK] BIGBLOC_full -> BIGBLOC.NS (Bigbloc Construction Limited)
# [OK] BHARTIARTL_full -> BHARTIARTL.NS (Bharti Airtel Limited)
# [OK] BHAGYANGR_full -> BHAGYANGR.NS (Bhagyanagar India Limited)
# [OK] BIKAJI_full -> BIKAJI.NS (Bikaji Foods International Limited)
# [OK] BILVYAPAR_full -> BILVYAPAR.NS (BIL Vyapar Limited)
# [OK] BIOCON_full -> BIOCON.NS (Biocon Limited)
# [OK] BIRLACORPN_full -> BIRLACORPN.NS (Birla Corporation Limited)
# [OK] BIL_full -> BIL.NS (Bhartiya International Ltd.)
# [OK] BIRLACABLE_full -> BIRLACABLE.NS (Birla Cable Limited)
# [OK] BIOFILCHEM_full -> BIOFILCHEM.NS (Biofil Chemicals and Pharmaceuticals Limited)
# [OK] BLAL_full -> BLAL.NS (BEML Land Assets Limited)
# [OK] BIRLAMONEY_full -> BIRLAMONEY.NS (Aditya Birla Money Limited)
# [OK] BIRLANU_full -> BIRLANU.NS (BirlaNu Limited)
# [OK] BLACKBUCK_full -> BLACKBUCK.NS (BlackBuck Limited)
# [OK] BLISSGVS_full -> BLISSGVS.NS (Bliss GVS Pharma Limited)
# [OK] BLKASHYAP_full -> BLKASHYAP.NS (B.L. Kashyap and Sons Limited)
# [OK] BLBLIMITED_full -> BLBLIMITED.NS (BLB Limited)
# [OK] BLUEDART_full -> BLUEDART.NS (Blue Dart Express Limited)
# [OK] BLUECOAST_full -> BLUECOAST.NS (Blue Coast Hotels Limited)
# [OK] BLUEJET_full -> BLUEJET.NS (Blue Jet Healthcare Limited)
# [OK] BLS_full -> BLS.NS (BLS International Services Limited)
# [OK] BLSE_full -> BLSE.NS (BLS E-SERVICES LIMITED)
# [OK] BLUESTARCO_full -> BLUESTARCO.NS (Blue Star Limited)
# [OK] BLUSPRING_full -> BLUSPRING.NS (Bluspring Enterprises Limited)
# [OK] BOHRAIND_full -> BOHRAIND.NS (Bohra Industries Limited)
# [OK] BODALCHEM_full -> BODALCHEM.NS (Bodal Chemicals Limited)
# [OK] BORANA_full -> BORANA.NS (BORANA WEAVES LIMITED)
# [OK] BOMDYEING_full -> BOMDYEING.NS (The Bombay Dyeing and Manufacturing Company Limited)
# [OK] BOROLTD_full -> BOROLTD.NS (Borosil Limited)
# [OK] BOROSCI_full -> BOROSCI.NS (Borosil Scientific Limited)
# [OK] BORORENEW_full -> BORORENEW.NS (Borosil Renewables Limited)
# [OK] BPL_full -> BPL.NS (BPL Limited)
# [OK] BRIGADE_full -> BRIGADE.NS (Brigade Enterprises Limited)
# [OK] BOSCHLTD_full -> BOSCHLTD.NS (Bosch Limited)
# [OK] BRNL_full -> BRNL.NS (Bharat Road Network Limited)
# [OK] BRIGHOTEL_full -> BRIGHOTEL.NS (BRIGADE HOTEL VENTURE LTD)
# [OK] BPCL_full -> BPCL.NS (Bharat Petroleum Corporation Limited)
# [OK] BROOKS_full -> BROOKS.NS (Brooks Laboratories Limited)
# [OK] BSHSL_full -> BSHSL.NS (Bombay Super Hybrid Seeds Limited)
# [OK] BRITANNIA_full -> BRITANNIA.NS (Britannia Industries Limited)
# [OK] BSL_full -> BSL.NS (BSL Limited)
# [OK] BSE_full -> BSE.NS (BSE Limited)
# [OK] BYKE_full -> BYKE.NS (The Byke Hospitality Limited)
# [OK] BSOFT_full -> BSOFT.NS (Birlasoft Limited)
# [OK] BUTTERFLY_full -> BUTTERFLY.NS (Butterfly Gandhimathi Appliances Limited)
# [OK] BTML_full -> BTML.NS (Bodhi Tree Multimedia Limited)
# [OK] BVCL_full -> BVCL.NS (Barak Valley Cements Limited)
# [OK] CAMLINFINE_full -> CAMLINFINE.NS (Camlin Fine Sciences Limited)
# [OK] CAMS_full -> CAMS.NS (Computer Age Management Services Limited)
# [OK] CANBK_full -> CANBK.NS (Canara Bank)
# [OK] CANFINHOME_full -> CANFINHOME.NS (Can Fin Homes Limited)
# [OK] CAPITALSFB_full -> CAPITALSFB.NS (Capital Small Finance Bank Limited)
# [OK] CAPACITE_full -> CAPACITE.NS (Capacit'e Infraprojects Limited)
# [OK] CAMPUS_full -> CAMPUS.NS (Campus Activewear Limited)
# [OK] CAPLIPOINT_full -> CAPLIPOINT.NS (Caplin Point Laboratories Limited)
# [OK] CANTABIL_full -> CANTABIL.NS (Cantabil Retail India Limited)
# [OK] CAPTRUST_full -> CAPTRUST.NS (Capital Trust Limited)
# [OK] CARRARO_full -> CARRARO.NS (CARRARO INDIA LIMITED)
# [OK] CARBORUNIV_full -> CARBORUNIV.NS (Carborundum Universal Limited)
# [OK] CALSOFT_full -> CALSOFT.NS (California Software Company Limited)
# [OK] CARYSIL_full -> CARYSIL.NS (Carysil Limited)
# [OK] CARTRADE_full -> CARTRADE.NS (CarTrade Tech Limited)
# [OK] CASTROLIND_full -> CASTROLIND.NS (Castrol India Limited)
# [OK] CARERATING_full -> CARERATING.NS (CARE Ratings Limited)
# [OK] CCHHL_full -> CCHHL.NS (Country Club Hospitality & Holidays Limited)
# [OK] CCCL_full -> CCCL.NS (Consolidated Construction Consortium Limited)
# [OK] CDSL_full -> CDSL.NS (Central Depository Services (India) Limited)
# [OK] CCL_full -> CCL.NS (CCL Products (India) Limited)
# [OK] CEATLTD_full -> CEATLTD.NS (CEAT Limited)
# [OK] CEIGALL_full -> CEIGALL.NS (CEIGALL INDIA LIMITED)
# [OK] CENTENKA_full -> CENTENKA.NS (Century Enka Limited)
# [OK] CENTRALBK_full -> CENTRALBK.NS (Central Bank of India)
# [OK] CENTEXT_full -> CENTEXT.NS (Century Extrusions Limited)
# [OK] CELEBRITY_full -> CELEBRITY.NS (Celebrity Fashions Limited)
# [OK] CELLO_full -> CELLO.NS (Cello World Limited)
# [OK] CENTUM_full -> CENTUM.NS (Centum Electronics Limited)
# [OK] CENTRUM_full -> CENTRUM.NS (Centrum Capital Limited)
# [OK] CENTURYPLY_full -> CENTURYPLY.NS (Century Plyboards (India) Limited)
# [OK] CERA_full -> CERA.NS (Cera Sanitaryware Limited)
# [OK] CEWATER_full -> CEWATER.NS (CONCORD ENVIRO SYSTEMS L)
# [OK] CESC_full -> CESC.NS (CESC Limited)
# [OK] CEREBRAINT_full -> CEREBRAINT.NS (Cerebra Integrated Technologies Limited)
# [OK] CGCL_full -> CGCL.NS (Capri Global Capital Limited)
# [OK] CHEMBONDCH_full -> CHEMBONDCH.NS (Chembond Chemicals Limited)
# [OK] CHAMBLFERT_full -> CHAMBLFERT.NS (Chambal Fertilisers and Chemicals Limited)
# [OK] CHALET_full -> CHALET.NS (Chalet Hotels Limited)
# [OK] CHEMBOND_full -> CHEMBOND.NS (Chembond Material Technologies Limited)
# [OK] CHENNPETRO_full -> CHENNPETRO.NS (Chennai Petroleum Corporation Limited)
# [OK] CHEMCON_full -> CHEMCON.NS (Chemcon Speciality Chemicals Limited)
# [OK] CHEMFAB_full -> CHEMFAB.NS (Chemfab Alkalis Limited)
# [OK] CHEMPLASTS_full -> CHEMPLASTS.NS (Chemplast Sanmar Limited)
# [OK] CIEINDIA_full -> CIEINDIA.NS (CIE Automotive India Limited)
# [OK] CHOLAHLDNG_full -> CHOLAHLDNG.NS (Cholamandalam Financial Holdings Limited)
# [OK] CGPOWER_full -> CGPOWER.NS (CG Power and Industrial Solutions Limited)
# [OK] CHEVIOT_full -> CHEVIOT.NS (Cheviot Company Limited)
# [OK] CHOICEIN_full -> CHOICEIN.NS (Choice International Limited)
# [OK] CIFL_full -> CIFL.NS (Capital India Finance Limited)
# [OK] CHOLAFIN_full -> CHOLAFIN.NS (Cholamandalam Investment and Finance Company Limited)
# [OK] CIGNITITEC_full -> CIGNITITEC.NS (Cigniti Technologies Limited)
# [OK] CIPLA_full -> CIPLA.NS (Cipla Limited)
# [OK] CINELINE_full -> CINELINE.NS (Cineline India Limited)
# [OK] CLEDUCATE_full -> CLEDUCATE.NS (CL Educate Limited)
# [OK] CLSEL_full -> CLSEL.NS (Chaman Lal Setia Exports Ltd.)
# [OK] CINEVISTA_full -> CINEVISTA.NS (Cinevista Limited)
# [OK] CMSINFO_full -> CMSINFO.NS (CMS Info Systems Limited)
# [OK] CLEAN_full -> CLEAN.NS (Clean Science and Technology Limited)
# [OK] COASTCORP_full -> COASTCORP.NS (Coastal Corporation Limited)
# [OK] COFORGE_full -> COFORGE.NS (Coforge Limited)
# [OK] COALINDIA_full -> COALINDIA.NS (Coal India Limited)
# [OK] COCHINSHIP_full -> COCHINSHIP.NS (Cochin Shipyard Limited)
# [OK] COFFEEDAY_full -> COFFEEDAY.NS (Coffee Day Enterprises Limited)
# [OK] COHANCE_full -> COHANCE.NS (COHANCE LIFESCIENCES LTD)
# [OK] COLPAL_full -> COLPAL.NS (Colgate-Palmolive (India) Limited)
# [OK] COMPUSOFT_full -> COMPUSOFT.NS (Compucom Software Limited)
# [OK] CONCORDBIO_full -> CONCORDBIO.NS (Concord Biotech Limited)
# [OK] CONCOR_full -> CONCOR.NS (Container Corporation of India Limited)
# [OK] COMSYN_full -> COMSYN.NS (Commercial Syn Bags Limited)
# [OK] CONTROLPR_full -> CONTROLPR.NS (Control Print Limited)
# [OK] CONFIPET_full -> CONFIPET.NS (Confidence Petroleum India Limited)
# [OK] CONSOFINVT_full -> CONSOFINVT.NS (Consolidated Finvest & Holdings Limited)
# [OK] CORALFINAC_full -> CORALFINAC.NS (Coral India Finance and Housing Limited)
# [OK] CPCAP_full -> CPCAP.NS (CP Capital Limited)
# [OK] CORDSCABLE_full -> CORDSCABLE.NS (Cords Cable Industries Limited)
# [OK] COUNCODOS_full -> COUNCODOS.NS (Country Condo's Limited)
# [OK] COSMOFIRST_full -> COSMOFIRST.NS (Cosmo First Limited)
# [OK] COROMANDEL_full -> COROMANDEL.NS (Coromandel International Limited)
# [OK] CPPLUS_full -> CPPLUS.NS (ADITYA INFOTECH LIMITED)
# [OK] CRAFTSMAN_full -> CRAFTSMAN.NS (Craftsman Automation Limited)
# [OK] CREDITACC_full -> CREDITACC.NS (CreditAccess Grameen Limited)
# [OK] CREATIVE_full -> CREATIVE.NS (Creative Newtech Limited)
# [OK] CRISIL_full -> CRISIL.NS (CRISIL Limited)
# [OK] CRIZAC_full -> CRIZAC.NS (CRIZAC LIMITED)
# [OK] CROMPTON_full -> CROMPTON.NS (Crompton Greaves Consumer Electricals Limited)
# [OK] CROWN_full -> CROWN.NS (Crown Lifters Limited)
# [OK] CSLFINANCE_full -> CSLFINANCE.NS (CSL Finance Limited)
# [OK] CSBBANK_full -> CSBBANK.NS (CSB Bank Limited)
# [OK] CTE_full -> CTE.NS (Cambridge Technology Enterprises Limited)
# [OK] CUBEXTUB_full -> CUBEXTUB.NS (Cubex Tubings Limited)
# [OK] CUB_full -> CUB.NS (City Union Bank Limited)
# [OK] CUPID_full -> CUPID.NS (Cupid Limited)
# [OK] CUMMINSIND_full -> CUMMINSIND.NS (Cummins India Limited)
# [OK] CYBERMEDIA_full -> CYBERMEDIA.NS (Cyber Media (India) Limited)
# [OK] CURAA_full -> CURAA.NS (CURA TECHNOLOGIES LIMITED)
# [OK] CYBERTECH_full -> CYBERTECH.NS (CyberTech Systems and Software Limited)
# [OK] CYIENT_full -> CYIENT.NS (Cyient Limited)
# [OK] DABUR_full -> DABUR.NS (Dabur India Limited)
# [OK] CYIENTDLM_full -> CYIENTDLM.NS (Cyient DLM Limited)
# [OK] DALMIASUG_full -> DALMIASUG.NS (Dalmia Bharat Sugar and Industries Limited)
# [OK] DAMCAPITAL_full -> DAMCAPITAL.NS (DAM CAPITAL ADVISORS LTD)
# [OK] CREATIVEYE_full -> CREATIVEYE.NS (Creative Eye Limited)
# [OK] DALBHARAT_full -> DALBHARAT.NS (Dalmia Bharat Limited)
# [OK] DAMODARIND_full -> DAMODARIND.NS (Damodar Industries Limited)
# [OK] DANGEE_full -> DANGEE.NS (Dangee Dums Limited)
# [OK] DATAMATICS_full -> DATAMATICS.NS (Datamatics Global Services Limited)
# [OK] DATAPATTNS_full -> DATAPATTNS.NS (Data Patterns (India) Limited)
# [OK] DBCORP_full -> DBCORP.NS (D. B. Corp Limited)
# [OK] DAVANGERE_full -> DAVANGERE.NS (Davangere Sugar Company Limited)
# [OK] DBEIL_full -> DBEIL.NS (DEEPAK BUILDERS & ENG I L)
# [OK] DBL_full -> DBL.NS (Dilip Buildcon Limited)
# [OK] DBOL_full -> DBOL.NS (Dhampur Bio Organics Limited)
# [OK] DCAL_full -> DCAL.NS (Dishman Carbogen Amcis Limited)
# [OK] CREST_full -> CREST.NS (Crest Ventures Limited)
# [OK] DBREALTY_full -> DBREALTY.NS (Valor Estate Limited)
# [OK] DBSTOCKBRO_full -> DBSTOCKBRO.NS (DB (International) Stock Brokers Limited)
# [OK] DCBBANK_full -> DCBBANK.NS (DCB Bank Limited)
# [OK] DCI_full -> DCI.NS (DC Infotech and Communication Limited)
# [OK] DCMFINSERV_full -> DCMFINSERV.NS (DCM Financial Services Limited)
# [OK] DCM_full -> DCM.NS (DCM Limited)
# [OK] DCW_full -> DCW.NS (DCW Limited)
# [OK] DCMSHRIRAM_full -> DCMSHRIRAM.NS (DCM Shriram Limited)
# [OK] DCMSRIND_full -> DCMSRIND.NS (DCM Shriram Industries Limited)
# [OK] DECCANCE_full -> DECCANCE.NS (Deccan Cements Limited)
# [OK] DCMNVL_full -> DCMNVL.NS (DCM Nouvelle Limited)
# [OK] DDEVPLSTIK_full -> DDEVPLSTIK.NS (Ddev Plastiks Industries Limited)
# [OK] DEEPAKFERT_full -> DEEPAKFERT.NS (Deepak Fertilisers And Petrochemicals Corporation Limited)
# [OK] DCXINDIA_full -> DCXINDIA.NS (DCX Systems Limited)
# [OK] DEEPINDS_full -> DEEPINDS.NS (Deep Industries Limited)
# [OK] DEEPAKNTR_full -> DEEPAKNTR.NS (Deepak Nitrite Limited)
# [OK] DEEDEV_full -> DEEDEV.NS (DEE DEVELOPMENT ENG LTD)
# [OK] DELPHIFX_full -> DELPHIFX.NS (Delphi World Money Limited)
# [OK] DENORA_full -> DENORA.NS (De Nora India Limited)
# [OK] DELHIVERY_full -> DELHIVERY.NS (Delhivery Limited)
# [OK] DELTACORP_full -> DELTACORP.NS (Delta Corp Limited)
# [OK] DELTAMAGNT_full -> DELTAMAGNT.NS (Delta Manufacturing Limited)
# [OK] DENTA_full -> DENTA.NS (DENTA WATER N INFRA SOL L)
# [OK] DHAMPURSUG_full -> DHAMPURSUG.NS (Dhampur Sugar Mills Limited)
# [OK] DEVIT_full -> DEVIT.NS (Dev Information Technology Limited)
# [OK] DEVYANI_full -> DEVYANI.NS (Devyani International Limited)
# [OK] DHANBANK_full -> DHANBANK.NS (Dhanlaxmi Bank Limited)
# [OK] DEN_full -> DEN.NS (DEN Networks Limited)
# [OK] DGCONTENT_full -> DGCONTENT.NS (Digicontent Limited)
# [OK] DHARAN_full -> DHARAN.NS (Dharan Infra-EPC Limited)
# [OK] DHRUV_full -> DHRUV.NS (Dhruv Consultancy Services Limited)
# [OK] DHUNINV_full -> DHUNINV.NS (Dhunseri Investments Limited)
# [OK] DHANUKA_full -> DHANUKA.NS (Dhanuka Agritech Limited)
# [OK] DHARMAJ_full -> DHARMAJ.NS (Dharmaj Crop Guard Limited)
# [OK] DIAMONDYD_full -> DIAMONDYD.NS (Prataap Snacks Limited)
# [OK] DIACABS_full -> DIACABS.NS (Diamond Power Infrastructure Limited)
# [OK] DHANI_full -> DHANI.NS (Dhani Services Limited)
# [OK] DIFFNKG_full -> DIFFNKG.NS (DIFFUSION ENGINEERS LTD)
# [OK] DICIND_full -> DICIND.NS (DIC India Limited)
# [OK] DIAMINESQ_full -> DIAMINESQ.NS (Diamines and Chemicals Limited)
# [OK] DIGISPICE_full -> DIGISPICE.NS (DiGiSPICE Technologies Limited)
# [OK] DIGIDRIVE_full -> DIGIDRIVE.NS (Digidrive Distributors Limited)
# [OK] DIL_full -> DIL.NS (Debock Industries Limited)
# [OK] DIGITIDE_full -> DIGITIDE.NS (Digitide Solutions Limited)
# [OK] DIGJAMLMTD_full -> DIGJAMLMTD.NS (Digjam Limited)
# [OK] DIVGIITTS_full -> DIVGIITTS.NS (Divgi TorqTransfer Systems Limited)
# [OK] DIVISLAB_full -> DIVISLAB.NS (Divi's Laboratories Limited)
# [OK] DISHTV_full -> DISHTV.NS (Dish TV India Limited)
# [OK] DIXON_full -> DIXON.NS (Dixon Technologies (India) Limited)
# [OK] DJML_full -> DJML.NS (DJ Mediaprint & Logistics Limited)
# [OK] DLINKINDIA_full -> DLINKINDIA.NS (D-Link (India) Limited)
# [OK] DLF_full -> DLF.NS (DLF Limited)
# [OK] DMART_full -> DMART.NS (Avenue Supermarts Limited)
# [OK] DMCC_full -> DMCC.NS (DMCC Speciality Chemicals Limited)
# [OK] DNAMEDIA_full -> DNAMEDIA.NS (Diligent Media Corporation Limited)
# [OK] DOLATALGO_full -> DOLATALGO.NS (Dolat Algotech Limited)
# [OK] DODLA_full -> DODLA.NS (Dodla Dairy Limited)
# [OK] DOMS_full -> DOMS.NS (DOMS Industries Limited)
# [OK] DONEAR_full -> DONEAR.NS (Donear Industries Limited)
# [OK] DOLPHIN_full -> DOLPHIN.NS (Dolphin Offshore Enterprises (India) Limited)
# [OK] DPSCLTD_full -> DPSCLTD.NS (India Power Corporation Limited)
# [OK] DOLLAR_full -> DOLLAR.NS (Dollar Industries Limited)
# [OK] DRCSYSTEMS_full -> DRCSYSTEMS.NS (DRC Systems India Limited)
# [OK] DPABHUSHAN_full -> DPABHUSHAN.NS (D. P. Abhushan Limited)
# [OK] DPWIRES_full -> DPWIRES.NS (D.P. Wires Limited)
# [OK] DREAMFOLKS_full -> DREAMFOLKS.NS (Dreamfolks Services Limited)
# [OK] DSSL_full -> DSSL.NS (Dynacons Systems & Solutions Limited)
# [OK] DTIL_full -> DTIL.NS (Dhunseri Tea & Industries Limited)
# [OK] DREDGECORP_full -> DREDGECORP.NS (Dredging Corporation of India Limited)
# [OK] DVL_full -> DVL.NS (Dhunseri Ventures Limited)
# [OK] DRREDDY_full -> DRREDDY.NS (Dr. Reddy's Laboratories Limited)
# [OK] DWARKESH_full -> DWARKESH.NS (Dwarikesh Sugar Industries Limited)
# [OK] DYCL_full -> DYCL.NS (Dynamic Cables Limited)
# [OK] DUCON_full -> DUCON.NS (Ducon Infratechnologies Limited)
# [OK] DYNAMATECH_full -> DYNAMATECH.NS (Dynamatic Technologies Limited)
# [OK] EBGNG_full -> EBGNG.NS (GNG ELECTRONICS LIMITED)
# [OK] ECLERX_full -> ECLERX.NS (eClerx Services Limited)
# [OK] EASEMYTRIP_full -> EASEMYTRIP.NS (Easy Trip Planners Limited)
# [OK] DYNPRO_full -> DYNPRO.NS (Dynemic Products Limited)
# [OK] E2E_full -> E2E.NS (E2E Networks Limited)
# [OK] ECOSMOBLTY_full -> ECOSMOBLTY.NS (ECOS (INDIA) MOB & HOSP L)
# [OK] EDELWEISS_full -> EDELWEISS.NS (Edelweiss Financial Services Limited)
# [OK] EICHERMOT_full -> EICHERMOT.NS (Eicher Motors Limited)
# [OK] EIFFL_full -> EIFFL.NS (Euro India Fresh Foods Limited)
# [OK] EIEL_full -> EIEL.NS (ENVIRO INFRA ENGINEERS L)
# [OK] EIDPARRY_full -> EIDPARRY.NS (E.I.D.- Parry (India) Limited)
# [OK] EIHAHOTELS_full -> EIHAHOTELS.NS (EIH Associated Hotels Limited)
# [OK] EIMCOELECO_full -> EIMCOELECO.NS (Eimco Elecon (India) Limited)
# [OK] EIHOTEL_full -> EIHOTEL.NS (EIH Limited)
# [OK] ELECON_full -> ELECON.NS (Elecon Engineering Company Limited)
# [OK] EKC_full -> EKC.NS (Everest Kanto Cylinder Limited)
# [OK] ELDEHSG_full -> ELDEHSG.NS (Eldeco Housing and Industries Limited)
# [OK] ELECTHERM_full -> ELECTHERM.NS (Electrotherm (India) Limited)
# [OK] ELECTCAST_full -> ELECTCAST.NS (Electrosteel Castings Limited)
# [OK] ELIN_full -> ELIN.NS (Elin Electronics Limited)
# [OK] ELGIEQUIP_full -> ELGIEQUIP.NS (Elgi Equipments Limited)
# [OK] ELLEN_full -> ELLEN.NS (ELLENBARRIE INDUS GASES L)
# [OK] EMBDL_full -> EMBDL.NS (Embassy Developments Limited)
# [OK] EMCURE_full -> EMCURE.NS (EMCURE PHARMACEUTICALS L)
# [OK] EMAMILTD_full -> EMAMILTD.NS (Emami Limited)
# [OK] EMAMIREAL_full -> EMAMIREAL.NS (Emami Realty Limited)
# [OK] EMIL_full -> EMIL.NS (Electronics Mart India Limited)
# [OK] EMAMIPAP_full -> EMAMIPAP.NS (Emami Paper Mills Limited)
# [OK] EMMBI_full -> EMMBI.NS (Emmbi Industries Limited)
# [OK] ELGIRUBCO_full -> ELGIRUBCO.NS (Elgi Rubber Company Limited)
# [OK] EMKAY_full -> EMKAY.NS (Emkay Global Financial Services Limited)
# [OK] EMSLIMITED_full -> EMSLIMITED.NS (EMS Limited)
# [OK] EMUDHRA_full -> EMUDHRA.NS (eMudhra Limited)
# [OK] ENERGYDEV_full -> ENERGYDEV.NS (Energy Development Company Limited)
# [OK] ENDURANCE_full -> ENDURANCE.NS (Endurance Technologies Limited)
# [OK] ENTERO_full -> ENTERO.NS (Entero Healthcare Solutions Limited)
# [OK] ENIL_full -> ENIL.NS (Entertainment Network (India) Limited)
# [OK] ENRIN_full -> ENRIN.NS (Siemens Energy India Limited)
# [OK] ENGINERSIN_full -> ENGINERSIN.NS (Engineers India Limited)
# [OK] EPIGRAL_full -> EPIGRAL.NS (Epigral Limited)
# [OK] EPACK_full -> EPACK.NS (EPACK Durable Limited)
# [OK] EPL_full -> EPL.NS (EPL Limited)
# [OK] EQUIPPP_full -> EQUIPPP.NS (Equippp Social Impact Technologies Limited)
# [OK] EQUITASBNK_full -> EQUITASBNK.NS (Equitas Small Finance Bank Limited)
# [OK] ESABINDIA_full -> ESABINDIA.NS (ESAB India Limited)
# [OK] ERIS_full -> ERIS.NS (Eris Lifesciences Limited)
# [OK] ESCORTS_full -> ESCORTS.NS (Escorts Kubota Limited)
# [OK] ESSARSHPNG_full -> ESSARSHPNG.NS (Essar Shipping Limited)
# [OK] ESSENTIA_full -> ESSENTIA.NS (Integra Essentia Limited)
# [OK] ESAFSFB_full -> ESAFSFB.NS (ESAF Small Finance Bank)
# [OK] EUREKAFORB_full -> EUREKAFORB.NS (Eureka Forbes Limited)
# [OK] ESTER_full -> ESTER.NS (Ester Industries Limited)
# [OK] ETHOSLTD_full -> ETHOSLTD.NS (Ethos Limited)
# [OK] EUROBOND_full -> EUROBOND.NS (EURO PANEL PRODUCTS LTD)
# [OK] ETERNAL_full -> ETERNAL.NS (Eternal Limited)
# [OK] EUROTEXIND_full -> EUROTEXIND.NS (Eurotex Industries and Exports Limited)
# [OK] EVEREADY_full -> EVEREADY.NS (Eveready Industries India Limited)
# [OK] EVERESTIND_full -> EVERESTIND.NS (Everest Industries Limited)
# [OK] EXCEL_full -> EXCEL.NS (Excel Realty N Infra Limited)
# [OK] EXCELINDUS_full -> EXCELINDUS.NS (Excel Industries Limited)
# [OK] EXPLEOSOL_full -> EXPLEOSOL.NS (Expleo Solutions Limited)
# [OK] EXICOM_full -> EXICOM.NS (Exicom Tele-Systems Limited)
# [OK] EXIDEIND_full -> EXIDEIND.NS (Exide Industries Limited)
# [OK] FACT_full -> FACT.NS (The Fertilisers and Chemicals Travancore Limited)
# [OK] EXXARO_full -> EXXARO.NS (Exxaro Tiles Limited)
# [OK] FAIRCHEMOR_full -> FAIRCHEMOR.NS (Fairchem Organics Limited)
# [OK] FAZE3Q_full -> FAZE3Q.NS (Faze Three Limited)
# [OK] FCL_full -> FCL.NS (Fineotex Chemical Limited)
# [OK] FDC_full -> FDC.NS (FDC Limited)
# [OK] FEDERALBNK_full -> FEDERALBNK.NS (The Federal Bank Limited)
# [OK] FCSSOFT_full -> FCSSOFT.NS (FCS Software Solutions Limited)
# [OK] FELDVR_full -> FELDVR.NS (Future Enterprises Limited)
# [OK] FEDFINA_full -> FEDFINA.NS (Fedbank Financial Services Limited)
# [OK] FIBERWEB_full -> FIBERWEB.NS (Fiberweb (India) Limited)
# [OK] FEL_full -> FEL.NS (Future Enterprises Limited)
# [OK] FILATFASH_full -> FILATFASH.NS (Filatex Fashions Limited)
# [OK] FILATEX_full -> FILATEX.NS (Filatex India Limited)
# [OK] FIEMIND_full -> FIEMIND.NS (Fiem Industries Limited)
# [OK] FINPIPE_full -> FINPIPE.NS (Finolex Industries Limited)
# [OK] FINOPB_full -> FINOPB.NS (Fino Payments Bank Limited)
# [OK] FINCABLES_full -> FINCABLES.NS (Finolex Cables Limited)
# [OK] FINEORG_full -> FINEORG.NS (Fine Organic Industries Limited)
# [OK] FIRSTCRY_full -> FIRSTCRY.NS (BRAINBEES SOLUTIONS LTD)
# [OK] FIVESTAR_full -> FIVESTAR.NS (Five-Star Business Finance Limited)
# [OK] FISCHER_full -> FISCHER.NS (Fischer Medical Ventures Limited)
# [OK] FLAIR_full -> FLAIR.NS (FLAIR WRITING INDUST LTD)
# [OK] FMNL_full -> FMNL.NS (Future Market Networks Limited)
# [OK] FLEXITUFF_full -> FLEXITUFF.NS (Flexituff Ventures International Limited)
# [OK] FLUOROCHEM_full -> FLUOROCHEM.NS (Gujarat Fluorochemicals Limited)
# [OK] FOCUS_full -> FOCUS.NS (Focus Lighting and Fixtures Limited)
# [OK] FMGOETZE_full -> FMGOETZE.NS (Federal-Mogul Goetze (India) Limited)
# [OK] FORCEMOT_full -> FORCEMOT.NS (Force Motors Limited)
# [OK] FOODSIN_full -> FOODSIN.NS (Foods and Inns Limited)
# [OK] FORTIS_full -> FORTIS.NS (Fortis Healthcare Limited)
# [OK] FOSECOIND_full -> FOSECOIND.NS (Foseco India Limited)
# [OK] FUSION_full -> FUSION.NS (Fusion Finance Limited)
# [OK] FSL_full -> FSL.NS (Firstsource Solutions Limited)
# [OK] GABRIEL_full -> GABRIEL.NS (Gabriel India Limited)
# [OK] GAEL_full -> GAEL.NS (Gujarat Ambuja Exports Limited)
# [OK] GALAPREC_full -> GALAPREC.NS (GALA PRECISION ENG LTD)
# [OK] GAIL_full -> GAIL.NS (GAIL (India) Limited)
# [OK] GANDHAR_full -> GANDHAR.NS (Gandhar Oil Refinery (India) Limited)
# [OK] GALLANTT_full -> GALLANTT.NS (Gallantt Ispat Limited)
# [OK] GALAXYSURF_full -> GALAXYSURF.NS (Galaxy Surfactants Limited)
# [OK] GANDHITUBE_full -> GANDHITUBE.NS (Gandhi Special Tubes Limited)
# [OK] GANESHHOUC_full -> GANESHHOUC.NS (Ganesh Housing Limited)
# [OK] GANECOS_full -> GANECOS.NS (Ganesha Ecosphere Limited)
# [OK] GANGAFORGE_full -> GANGAFORGE.NS (Ganga Forging Limited)
# [OK] GANESHBE_full -> GANESHBE.NS (Ganesh Benzoplast Limited)
# [OK] GARUDA_full -> GARUDA.NS (GARUDA CONSTRUCT N ENG L)
# [OK] GANGESSECU_full -> GANGESSECU.NS (Ganges Securities Limited)
# [OK] GARFIBRES_full -> GARFIBRES.NS (Garware Technical Fibres Limited)
# [OK] GATECHDVR_full -> GATECHDVR.NS (GACM Technologies Limited)
# [OK] GATEWAY_full -> GATEWAY.NS (Gateway Distriparks Limited)
# [OK] GEECEE_full -> GEECEE.NS (GeeCee Ventures Limited)
# [OK] GAYAPROJ_full -> GAYAPROJ.NS (Gayatri Projects Limited)
# [OK] GAYAHWS_full -> GAYAHWS.NS (Gayatri Highways Limited)
# [OK] GATECH_full -> GATECH.NS (GACM Technologies Limited)
# [OK] GEEKAYWIRE_full -> GEEKAYWIRE.NS (Geekay Wires Limited)
# [OK] GEOJITFSL_full -> GEOJITFSL.NS (Geojit Financial Services Limited)
# [OK] GENUSPOWER_full -> GENUSPOWER.NS (Genus Power Infrastructures Limited)
# [OK] GENESYS_full -> GENESYS.NS (Genesys International Corporation Limited)
# [OK] GENUSPAPER_full -> GENUSPAPER.NS (Genus Paper & Boards Limited)
# [OK] GENCON_full -> GENCON.NS (Generic Engineering Construction and Projects Limited)
# [OK] GEPIL_full -> GEPIL.NS (GE Power India Limited)
# [OK] GHCLTEXTIL_full -> GHCLTEXTIL.NS (GHCL Textiles Limited)
# [OK] GFLLIMITED_full -> GFLLIMITED.NS (GFL Limited)
# [OK] GILLETTE_full -> GILLETTE.NS (Gillette India Limited)
# [OK] GICHSGFIN_full -> GICHSGFIN.NS (GIC Housing Finance Limited)
# [OK] GICRE_full -> GICRE.NS (General Insurance Corporation of India)
# [OK] GILLANDERS_full -> GILLANDERS.NS (Gillanders Arbuthnot and Company Limited)
# [OK] GHCL_full -> GHCL.NS (GHCL Limited)
# [OK] GINNIFILA_full -> GINNIFILA.NS (Ginni Filaments Limited)
# [OK] GKWLIMITED_full -> GKWLIMITED.NS (GKW Limited)
# [OK] GLAND_full -> GLAND.NS (Gland Pharma Limited)
# [OK] GIPCL_full -> GIPCL.NS (Gujarat Industries Power Company Limited)
# [OK] GLENMARK_full -> GLENMARK.NS (Glenmark Pharmaceuticals Limited)
# [OK] GESHIP_full -> GESHIP.NS (The Great Eastern Shipping Company Limited)
# [OK] GLFL_full -> GLFL.NS (Gujarat Lease Financing Limited)
# [OK] GLOBALE_full -> GLOBALE.NS (Globale Tessile Limited)
# [OK] GLAXO_full -> GLAXO.NS (GlaxoSmithKline Pharmaceuticals Limited)
# [OK] GLOBALVECT_full -> GLOBALVECT.NS (Global Vectra Helicorp Limited)
# [OK] GLOBECIVIL_full -> GLOBECIVIL.NS (GLOBE CIVIL PROJECTS LTD)
# [OK] GLOBE_full -> GLOBE.NS (Globe Textiles (India) Limited)
# [OK] GLOBUSSPR_full -> GLOBUSSPR.NS (Globus Spirits Limited)
# [OK] GLOBAL_full -> GLOBAL.NS (Global Education Limited)
# [OK] GLOSTERLTD_full -> GLOSTERLTD.NS (Gloster Limited)
# [OK] GMDCLTD_full -> GMDCLTD.NS (Gujarat Mineral Development Corporation Limited)
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: GMRPUI.NS"}}}
# [OK] GMBREW_full -> GMBREW.NS (G.M. Breweries Limited)
# [OK] GMMPFAUDLR_full -> GMMPFAUDLR.NS (GMM Pfaudler Limited)
# [OK] GNA_full -> GNA.NS (G N A Axles Limited)
# [OK] GMRAIRPORT_full -> GMRAIRPORT.NS (GMR Airports Limited)
# [OK] GOCLCORP_full -> GOCLCORP.NS (GOCL Corporation Limited)
# [OK] GOACARBON_full -> GOACARBON.NS (Goa Carbon Limited)
# [OK] GODAVARIB_full -> GODAVARIB.NS (GODAVARI BIOREFINERIES L)
# [OK] GNFC_full -> GNFC.NS (Gujarat Narmada Valley Fertilizers & Chemicals Limited)
# [OK] GOCOLORS_full -> GOCOLORS.NS (Go Fashion (India) Limited)
# [OK] GODIGIT_full -> GODIGIT.NS (GO DIGIT GENERAL INS LTD)
# [OK] GODFRYPHLP_full -> GODFRYPHLP.NS (Godfrey Phillips India Limited)
# [OK] GODREJCP_full -> GODREJCP.NS (Godrej Consumer Products Limited)
# [OK] GODREJIND_full -> GODREJIND.NS (Godrej Industries Limited)
# [OK] GODREJAGRO_full -> GODREJAGRO.NS (Godrej Agrovet Limited)
# [OK] GOENKA_full -> GOENKA.NS (Goenka Diamond and Jewels Limited)
# [OK] GODHA_full -> GODHA.NS (Godha Cabcon & Insulation Limited)
# [OK] GOKULAGRO_full -> GOKULAGRO.NS (Gokul Agro Resources Limited)
# [OK] GOKEX_full -> GOKEX.NS (Gokaldas Exports Limited)
# [OK] GODREJPROP_full -> GODREJPROP.NS (Godrej Properties Limited)
# [OK] GOLDIAM_full -> GOLDIAM.NS (Goldiam International Limited)
# [OK] GOKUL_full -> GOKUL.NS (Gokul Refoils & Solvent Limited)
# [OK] GOODLUCK_full -> GOODLUCK.NS (Goodluck India Limited)
# [OK] GOLDENTOBC_full -> GOLDENTOBC.NS (Golden Tobacco Limited)
# [OK] GOLDTECH_full -> GOLDTECH.NS (AION-TECH Solutions Limited)
# [OK] GOPAL_full -> GOPAL.NS (Gopal Snacks Limited)
# [OK] GPIL_full -> GPIL.NS (Godawari Power & Ispat Limited)
# [OK] GPTINFRA_full -> GPTINFRA.NS (GPT Infraprojects Limited)
# [OK] GPTHEALTH_full -> GPTHEALTH.NS (GPT Healthcare Limited)
# [OK] GOYALALUM_full -> GOYALALUM.NS (Goyal Aluminiums Limited)
# [OK] GPPL_full -> GPPL.NS (Gujarat Pipavav Port Limited)
# [OK] GRANULES_full -> GRANULES.NS (Granules India Limited)
# [OK] GRASIM_full -> GRASIM.NS (Grasim Industries Limited)
# [OK] GRAPHITE_full -> GRAPHITE.NS (Graphite India Limited)
# [OK] GRAVITA_full -> GRAVITA.NS (Gravita India Limited)
# [OK] GREENPANEL_full -> GREENPANEL.NS (Greenpanel Industries Limited)
# [OK] GREENLAM_full -> GREENLAM.NS (Greenlam Industries Limited)
# [OK] GREAVESCOT_full -> GREAVESCOT.NS (Greaves Cotton Limited)
# [OK] GREENPOWER_full -> GREENPOWER.NS (Orient Green Power Company Limited)
# [OK] GRINDWELL_full -> GRINDWELL.NS (Grindwell Norton Limited)
# [OK] GREENPLY_full -> GREENPLY.NS (Greenply Industries Limited)
# [OK] GROBTEA_full -> GROBTEA.NS (The Grob Tea Company Limited)
# [OK] GRPLTD_full -> GRPLTD.NS (GRP Limited)
# [OK] GRINFRA_full -> GRINFRA.NS (G R Infraprojects Limited)
# [OK] GRSE_full -> GRSE.NS (Garden Reach Shipbuilders & Engineers Limited)
# [OK] GRWRHITECH_full -> GRWRHITECH.NS (Garware Hi-Tech Films Limited)
# [OK] GSPL_full -> GSPL.NS (Gujarat State Petronet Limited)
# [OK] GRMOVER_full -> GRMOVER.NS (GRM Overseas Limited)
# [OK] GSLSU_full -> GSLSU.NS (Global Surfaces Limited)
# [OK] GSFC_full -> GSFC.NS (Gujarat State Fertilizers & Chemicals Limited)
# [OK] GTECJAINX_full -> GTECJAINX.NS (G-Tec Jainx Education Limited)
# [OK] GSS_full -> GSS.NS (GSS Infotech Limited)
# [OK] GTLINFRA_full -> GTLINFRA.NS (GTL Infrastructure Limited)
# [OK] GTL_full -> GTL.NS (GTL Limited)
# [OK] GUJALKALI_full -> GUJALKALI.NS (Gujarat Alkalies and Chemicals Limited)
# [OK] GUJRAFFIA_full -> GUJRAFFIA.NS (Gujarat Raffia Industries Limited)
# [OK] GUJGASLTD_full -> GUJGASLTD.NS (Gujarat Gas Limited)
# [OK] GUFICBIO_full -> GUFICBIO.NS (Gufic Biosciences Limited)
# [OK] GUJAPOLLO_full -> GUJAPOLLO.NS (Gujarat Apollo Industries Limited)
# [OK] GUJTHEM_full -> GUJTHEM.NS (Gujarat Themis Biosyn Limited)
# [OK] GULFOILLUB_full -> GULFOILLUB.NS (Gulf Oil Lubricants India Limited)
# [OK] GTPL_full -> GTPL.NS (GTPL Hathway Limited)
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: GVTD.NS"}}}
# [OK] GULFPETRO_full -> GULFPETRO.NS (GP Petroleums Limited)
# [OK] GULPOLY_full -> GULPOLY.NS (Gulshan Polyols Limited)
# [OK] GVPTECH_full -> GVPTECH.NS (GVP Infotech Limited)
# [OK] GVKPIL_full -> GVKPIL.NS (GVK Power & Infrastructure Limited)
# [OK] HAPPSTMNDS_full -> HAPPSTMNDS.NS (Happiest Minds Technologies Limited)
# [OK] HAL_full -> HAL.NS (Hindustan Aeronautics Limited)
# [FAIL] GMRPUI_full -> Not resolved. Tried: ['GMRPUI.NS']. Suggestions from search: ['GMRPUI.NS'].
# [OK] HAPPYFORGE_full -> HAPPYFORGE.NS (HAPPY FORGINGS LIMITED)
# [OK] HARSHA_full -> HARSHA.NS (Harsha Engineers International Limited)
# [OK] HARRMALAYA_full -> HARRMALAYA.NS (Harrisons Malayalam Limited)
# [OK] HARIOMPIPE_full -> HARIOMPIPE.NS (Hariom Pipe Industries Limited)
# [OK] HARDWYN_full -> HARDWYN.NS (Hardwyn India Limited)
# [OK] HATHWAY_full -> HATHWAY.NS (Hathway Cable and Datacom Limited)
# [OK] HAVISHA_full -> HAVISHA.NS (Sri Havisha Hospitality and Infrastructure Limited)
# [OK] HATSUN_full -> HATSUN.NS (Hatsun Agro Product Limited)
# [OK] HBLENGINE_full -> HBLENGINE.NS (HBL ENGINEERING LTD)
# [OK] HAVELLS_full -> HAVELLS.NS (Havells India Limited)
# [OK] HBSL_full -> HBSL.NS (HB Stockholdings Limited)
# [OK] HCL-INSYS_full -> HCL-INSYS.NS (HCL Infosystems Limited)
# [OK] HCLTECH_full -> HCLTECH.NS (HCL Technologies Limited)
# [OK] HCG_full -> HCG.NS (HealthCare Global Enterprises Limited)
# [OK] HCC_full -> HCC.NS (Hindustan Construction Company Limited)
# [OK] HDBFS_full -> HDBFS.NS (HDB FINANCIAL SERVICES L)
# [OK] HDFCBANK_full -> HDFCBANK.NS (HDFC Bank Limited)
# [OK] HDFCAMC_full -> HDFCAMC.NS (HDFC Asset Management Company Limited)
# [OK] HEADSUP_full -> HEADSUP.NS (Heads UP Ventures Limited)
# [OK] HDFCLIFE_full -> HDFCLIFE.NS (HDFC Life Insurance Company Limited)
# [OK] HEIDELBERG_full -> HEIDELBERG.NS (HeidelbergCement India Limited)
# [OK] HECPROJECT_full -> HECPROJECT.NS (HEC Infra Projects Limited)
# [OK] HEG_full -> HEG.NS (HEG Limited)
# [OK] HDIL_full -> HDIL.NS (Housing Development and Infrastructure Limited)
# [OK] HERANBA_full -> HERANBA.NS (Heranba Industries Limited)
# [OK] HERCULES_full -> HERCULES.NS (Hercules Hoists Limited)
# [OK] HERITGFOOD_full -> HERITGFOOD.NS (Heritage Foods Limited)
# [OK] HESTERBIO_full -> HESTERBIO.NS (Hester Biosciences Limited)
# [OK] HEMIPROP_full -> HEMIPROP.NS (Hemisphere Properties India Limited)
# [OK] HEUBACHIND_full -> HEUBACHIND.NS (Heubach Colorants India Limited)
# [OK] HEXATRADEX_full -> HEXATRADEX.NS (Hexa Tradex Limited)
# [OK] HEROMOTOCO_full -> HEROMOTOCO.NS (Hero MotoCorp Limited)
# ...
# [OK] TAINWALCHM_full -> TAINWALCHM.NS (Tainwala Chemicals and Plastics (India) Limited)
# [OK] TARACHAND_full -> TARACHAND.NS (Tara Chand Infralogistic Solutions Limited)
# [OK] TARMAT_full -> TARMAT.NS (Tarmat Limited)
# [OK] TARC_full -> TARC.NS (TARC Limited)
# [OK] TARIL_full -> TARIL.NS (TRANS & RECTI. LTD)
# [OK] TASTYBITE_full -> TASTYBITE.NS (Tasty Bite Eatables Limited)
# [OK] TARSONS_full -> TARSONS.NS (Tarsons Products Limited)
# [OK] TATACHEM_full -> TATACHEM.NS (Tata Chemicals Limited)
# [OK] TATACONSUM_full -> TATACONSUM.NS (Tata Consumer Products Limited)
# [OK] TATAELXSI_full -> TATAELXSI.NS (Tata Elxsi Limited)
# [OK] TATACOMM_full -> TATACOMM.NS (Tata Communications Limited)
# [OK] TATAMOTORS_full -> TATAMOTORS.NS (Tata Motors Limited)
# [OK] TATAINVEST_full -> TATAINVEST.NS (Tata Investment Corporation Limited)
# [OK] TATASTEEL_full -> TATASTEEL.NS (Tata Steel Limited)
# [OK] TATATECH_full -> TATATECH.NS (Tata Technologies Limited)
# [OK] TATAPOWER_full -> TATAPOWER.NS (Tata Power Company Limited)
# [OK] TATVA_full -> TATVA.NS (Tatva Chintan Pharma Chem Limited)
# [OK] TCIEXP_full -> TCIEXP.NS (TCI Express Limited)
# [OK] TCI_full -> TCI.NS (Transport Corporation of India Limited)
# [OK] TBZ_full -> TBZ.NS (Tribhovandas Bhimji Zaveri Limited)
# [OK] TBOTEK_full -> TBOTEK.NS (TBO TEK LIMITED)
# [OK] TCIFINANCE_full -> TCIFINANCE.NS (TCI Finance Limited)
# [OK] TCS_full -> TCS.NS (Tata Consultancy Services Limited)
# [OK] TECHM_full -> TECHM.NS (Tech Mahindra Limited)
# [OK] TDPOWERSYS_full -> TDPOWERSYS.NS (TD Power Systems Limited)
# [OK] TCPLPACK_full -> TCPLPACK.NS (TCPL Packaging Limited)
# [OK] TECILCHEM_full -> TECILCHEM.NS (Tecil Chemicals and Hydro Power Ltd.)
# [OK] TEGA_full -> TEGA.NS (Tega Industries Limited)
# [OK] TECHNOE_full -> TECHNOE.NS (Techno Electric & Engineering Company Limited)
# [OK] TEAMLEASE_full -> TEAMLEASE.NS (TeamLease Services Limited)
# [OK] TEJASNET_full -> TEJASNET.NS (Tejas Networks Limited)
# [OK] TEMBO_full -> TEMBO.NS (Tembo Global Industries Limited)
# [OK] TERASOFT_full -> TERASOFT.NS (Tera Software Limited)
# [OK] TFL_full -> TFL.NS (Transwarranty Finance Limited)
# [OK] TEXMOPIPES_full -> TEXMOPIPES.NS (Texmo Pipes and Products Limited)
# [OK] TFCILTD_full -> TFCILTD.NS (Tourism Finance Corporation of India Limited)
# [OK] TEXRAIL_full -> TEXRAIL.NS (Texmaco Rail & Engineering Limited)
# [OK] TEXINFRA_full -> TEXINFRA.NS (Texmaco Infrastructure & Holdings Limited)
# [FAIL] SURANATP_full -> Not resolved. Tried: ['SURANATP.NS']. Suggestions from search: ['SURANATP.NS'].
# [OK] THANGAMAYL_full -> THANGAMAYL.NS (Thangamayil Jewellery Limited)
# [OK] TGBHOTELS_full -> TGBHOTELS.NS (TGB Banquets and Hotels Limited)
# [OK] THEJO_full -> THEJO.NS (Thejo Engineering Limited)
# [OK] THELEELA_full -> THELEELA.NS (SCHLOSS BANGALORE LIMITED)
# [OK] THEINVEST_full -> THEINVEST.NS (The Investment Trust of India Limited)
# [OK] THOMASCOOK_full -> THOMASCOOK.NS (Thomas Cook (India) Limited)
# [OK] THEMISMED_full -> THEMISMED.NS (Themis Medicare Limited)
# [OK] THOMASCOTT_full -> THOMASCOTT.NS (Thomas Scott (India) Limited)
# [OK] TICL_full -> TICL.NS (Twamev Construction and Infrastructure Limited)
# [OK] TIIL_full -> TIIL.NS (Technocraft Industries (India) Limited)
# [OK] THYROCARE_full -> THYROCARE.NS (Thyrocare Technologies Limited)
# [OK] TIINDIA_full -> TIINDIA.NS (Tube Investments of India Limited)
# [OK] TIMETECHNO_full -> TIMETECHNO.NS (Time Technoplast Limited)
# [OK] TIJARIA_full -> TIJARIA.NS (Tijaria Polypipes Limited)
# [OK] TIL_full -> TIL.NS (TIL Limited)
# [OK] TINNARUBR_full -> TINNARUBR.NS (Tinna Rubber and Infrastructure Limited)
# [OK] TIMKEN_full -> TIMKEN.NS (Timken India Limited)
# [OK] THERMAX_full -> THERMAX.NS (Thermax Limited)
# [OK] TIPSMUSIC_full -> TIPSMUSIC.NS (Tips Music Limited)
# [OK] TIRUPATIFL_full -> TIRUPATIFL.NS (Tirupati Forge Limited)
# [OK] TIRUMALCHM_full -> TIRUMALCHM.NS (Thirumalai Chemicals Limited)
# [OK] TIPSFILMS_full -> TIPSFILMS.NS (Tips Films Limited)
# [OK] TITAGARH_full -> TITAGARH.NS (Titagarh Rail Systems Limited)
# [OK] TMB_full -> TMB.NS (Tamilnad Mercantile Bank Limited)
# [OK] TITAN_full -> TITAN.NS (Titan Company Limited)
# [OK] TI_full -> TI.NS (Tilaknagar Industries Ltd.)
# [OK] TNPL_full -> TNPL.NS (Tamil Nadu Newsprint and Papers Limited)
# [OK] TOKYOPLAST_full -> TOKYOPLAST.NS (Tokyo Plast International Limited)
# [OK] TOLINS_full -> TOLINS.NS (TOLINS TYRES LIMITED)
# [OK] TNPETRO_full -> TNPETRO.NS (Tamilnadu Petroproducts Limited)
# [OK] TORNTPHARM_full -> TORNTPHARM.NS (Torrent Pharmaceuticals Limited)
# [OK] TNTELE_full -> TNTELE.NS (Tamilnadu Telecommunications Limited)
# [OK] TOTAL_full -> TOTAL.NS (Total Transport Systems Limited)
# [OK] TORNTPOWER_full -> TORNTPOWER.NS (Torrent Power Limited)
# [OK] TPHQ_full -> TPHQ.NS (Teamo Productions HQ Limited)
# [OK] TRACXN_full -> TRACXN.NS (Tracxn Technologies Limited)
# [OK] TOUCHWOOD_full -> TOUCHWOOD.NS (Touchwood Entertainment Limited)
# [OK] TRANSWORLD_full -> TRANSWORLD.NS (Transworld Shipping Lines Limited)
# [OK] TPLPLASTEH_full -> TPLPLASTEH.NS (TPL Plastech Limited)
# [OK] TRANSRAILL_full -> TRANSRAILL.NS (TRANSRAIL LIGHTING LTD)
# [OK] TREJHARA_full -> TREJHARA.NS (Trejhara Solutions Limited)
# [OK] TRENT_full -> TRENT.NS (Trent Limited)
# [OK] TREL_full -> TREL.NS (Transindia Real Estate Limited)
# [OK] TRF_full -> TRF.NS (TRF Limited)
# [OK] TREEHOUSE_full -> TREEHOUSE.NS (Tree House Education & Accessories Limited)
# [OK] TRAVELFOOD_full -> TRAVELFOOD.NS (TRAVEL FOOD SERVICES LTD)
# [OK] TRIGYN_full -> TRIGYN.NS (Trigyn Technologies Limited)
# [OK] TRITURBINE_full -> TRITURBINE.NS (Triveni Turbine Limited)
# [OK] TRIVENI_full -> TRIVENI.NS (Triveni Engineering & Industries Limited)
# [OK] TRU_full -> TRU.NS (TruCap Finance Limited)
# [OK] TTL_full -> TTL.NS (T.T. Limited)
# [OK] TRIDENT_full -> TRIDENT.NS (Trident Limited)
# [OK] TTKHLTCARE_full -> TTKHLTCARE.NS (TTK Healthcare Limited)
# [OK] TVSELECT_full -> TVSELECT.NS (TVS Electronics Limited)
# [OK] TTML_full -> TTML.NS (Tata Teleservices (Maharashtra) Limited)
# [OK] TTKPRESTIG_full -> TTKPRESTIG.NS (TTK Prestige Limited)
# [OK] TVSHLTD_full -> TVSHLTD.NS (TVS Holdings Limited)
# [OK] TVSSCS_full -> TVSSCS.NS (TVS Supply Chain Solutions Limited)
# [OK] TVSMOTOR_full -> TVSMOTOR.NS (TVS Motor Company Limited)
# [OK] TVSSRICHAK_full -> TVSSRICHAK.NS (TVS Srichakra Limited)
# [OK] TVTODAY_full -> TVTODAY.NS (T.V. Today Network Limited)
# [OK] TVVISION_full -> TVVISION.NS (TV Vision Limited)
# [OK] UCOBANK_full -> UCOBANK.NS (UCO Bank)
# [OK] UBL_full -> UBL.NS (United Breweries Limited)
# [OK] UCAL_full -> UCAL.NS (UCAL Limited)
# [OK] UDAICEMENT_full -> UDAICEMENT.NS (Udaipur Cement Works Limited)
# [OK] UDS_full -> UDS.NS (Updater Services Limited)
# [OK] UFLEX_full -> UFLEX.NS (Uflex Limited)
# [OK] UGARSUGAR_full -> UGARSUGAR.NS (The Ugar Sugar Works Limited)
# [OK] UFO_full -> UFO.NS (UFO Moviez India Limited)
# [OK] UMESLTD_full -> UMESLTD.NS (Usha Martin Education & Solutions Limited)
# [OK] UMAEXPORTS_full -> UMAEXPORTS.NS (Uma Exports Limited)
# [OK] ULTRACEMCO_full -> ULTRACEMCO.NS (UltraTech Cement Limited)
# [OK] UGROCAP_full -> UGROCAP.NS (UGRO Capital Limited)
# [OK] UJJIVANSFB_full -> UJJIVANSFB.NS (Ujjivan Small Finance Bank Limited)
# [OK] UMIYA-MRO_full -> UMIYA-MRO.NS (Umiya Buildcon Limited)
# [OK] UNICHEMLAB_full -> UNICHEMLAB.NS (Unichem Laboratories Limited)
# [OK] UNIINFO_full -> UNIINFO.NS (Uniinfo Telecom Services Limited)
# [OK] UNIDT_full -> UNIDT.NS (United Drilling Tools Limited)
# [OK] UNIENTER_full -> UNIENTER.NS (Uniphos Enterprises Limited)
# [OK] UNIECOM_full -> UNIECOM.NS (UNICOMMERCE ESOLUTIONS L)
# [OK] UNIONBANK_full -> UNIONBANK.NS (Union Bank of India)
# [OK] UNIPARTS_full -> UNIPARTS.NS (Uniparts India Limited)
# [OK] UNITECH_full -> UNITECH.NS (Unitech Limited)
# [OK] UNITDSPR_full -> UNITDSPR.NS (UNITED SPIRITS LIMITED)
# [OK] UNIMECH_full -> UNIMECH.NS (UNIMECH AEROSPACE N MFG L)
# [OK] UNITEDPOLY_full -> UNITEDPOLY.NS (United Polyfab Gujarat Limited)
# [OK] UNIVPHOTO_full -> UNIVPHOTO.NS (Universus Photo Imagings Limited)
# [OK] UNIVASTU_full -> UNIVASTU.NS (Univastu India Limited)
# [OK] UNITEDTEA_full -> UNITEDTEA.NS (The United Nilgiri Tea Estates Company Limited)
# [OK] UNIVCABLES_full -> UNIVCABLES.NS (Universal Cables Limited)
# [OK] UPL_full -> UPL.NS (UPL Limited)
# [OK] UNOMINDA_full -> UNOMINDA.NS (Uno Minda Limited)
# [OK] URJA_full -> URJA.NS (Urja Global Limited)
# [OK] USHAMART_full -> USHAMART.NS (Usha Martin Limited)
# [OK] USK_full -> USK.NS (Udayshivakumar Infra Limited)
# [OK] UYFINCORP_full -> UYFINCORP.NS (U. Y. Fincorp Limited)
# [OK] V2RETAIL_full -> V2RETAIL.NS (V2 Retail Limited)
# [OK] UTKARSHBNK_full -> UTKARSHBNK.NS (Utkarsh Small Finance Bank Limited)
# [OK] UTIAMC_full -> UTIAMC.NS (UTI Asset Management Company Limited)
# [OK] UTTAMSUGAR_full -> UTTAMSUGAR.NS (Uttam Sugar Mills Limited)
# [OK] VAISHALI_full -> VAISHALI.NS (Vaishali Pharma Limited)
# [OK] VAIBHAVGBL_full -> VAIBHAVGBL.NS (Vaibhav Global Limited)
# [OK] VADILALIND_full -> VADILALIND.NS (Vadilal Industries Limited)
# [OK] VAKRANGEE_full -> VAKRANGEE.NS (Vakrangee Limited)
# [OK] VARDHACRLC_full -> VARDHACRLC.NS (Vardhman Acrylics Limited)
# [OK] URAVIDEF_full -> URAVIDEF.NS (Uravi Defence and Technology Limited)
# [OK] VALIANTORG_full -> VALIANTORG.NS (Valiant Organics Limited)
# [OK] VASCONEQ_full -> VASCONEQ.NS (Vascon Engineers Limited)
# [OK] VALIANTLAB_full -> VALIANTLAB.NS (Valiant Laboratories Limited)
# [OK] VARROC_full -> VARROC.NS (Varroc Engineering Limited)
# [OK] VARDMNPOLY_full -> VARDMNPOLY.NS (Vardhman Polytex Limited)
# [OK] VCL_full -> VCL.NS (Vaxtex Cotfab Limited)
# [OK] VBL_full -> VBL.NS (Varun Beverages Limited)
# [OK] VENKEYS_full -> VENKEYS.NS (Venky's (India) Limited)
# [OK] VEEDOL_full -> VEEDOL.NS (Veedol Corporation Limited)
# [OK] VENTIVE_full -> VENTIVE.NS (VENTIVE HOSPITALITY LTD)
# [OK] VASWANI_full -> VASWANI.NS (Vaswani Industries Limited)
# [OK] VERTOZ_full -> VERTOZ.NS (Vertoz Limited)
# [OK] VEDL_full -> VEDL.NS (Vedanta Limited)
# [OK] VENUSPIPES_full -> VENUSPIPES.NS (Venus Pipes and Tubes Limited)
# [OK] VENUSREM_full -> VENUSREM.NS (Venus Remedies Limited)
# [OK] VETO_full -> VETO.NS (Veto Switchgears and Cables Limited)
# [OK] VESUVIUS_full -> VESUVIUS.NS (Vesuvius India Limited)
# [OK] VERANDA_full -> VERANDA.NS (Veranda Learning Solutions Limited)
# [OK] VIDHIING_full -> VIDHIING.NS (Vidhi Specialty Food Ingredients Limited)
# [OK] VIJIFIN_full -> VIJIFIN.NS (Viji Finance Limited)
# [OK] VHL_full -> VHL.NS (Vardhman Holdings Limited)
# [OK] VIJAYA_full -> VIJAYA.NS (Vijaya Diagnostic Centre Limited)
# [OK] VIKASECO_full -> VIKASECO.NS (Vikas Ecotech Limited)
# [OK] VIMTALABS_full -> VIMTALABS.NS (Vimta Labs Limited)
# [OK] VHLTD_full -> VHLTD.NS (Viceroy Hotels Limited)
# [OK] VGUARD_full -> VGUARD.NS (V-Guard Industries Limited)
# [OK] VIKASLIFE_full -> VIKASLIFE.NS (Vikas Lifecare Limited)
# [OK] VINATIORGA_full -> VINATIORGA.NS (Vinati Organics Limited)
# [OK] VINCOFE_full -> VINCOFE.NS (Vintage Coffee and Beverages Limited)
# [OK] VINDHYATEL_full -> VINDHYATEL.NS (Vindhya Telelinks Limited)
# [OK] VINNY_full -> VINNY.NS (Vinny Overseas Limited)
# [OK] VIPIND_full -> VIPIND.NS (V.I.P. Industries Limited)
# [OK] VINEETLAB_full -> VINEETLAB.NS (Vineet Laboratories Limited)
# [OK] VIPULLTD_full -> VIPULLTD.NS (Vipul Limited)
# [OK] VINYLINDIA_full -> VINYLINDIA.NS (Vinyl Chemicals (India) Limited)
# [OK] VISAKAIND_full -> VISAKAIND.NS (Visaka Industries Limited)
# [OK] VISHNU_full -> VISHNU.NS (Vishnu Chemicals Limited)
# [OK] VISHWARAJ_full -> VISHWARAJ.NS (Vishwaraj Sugar Industries Limited)
# [OK] VIVIDHA_full -> VIVIDHA.NS (Visagar Polytex Limited)
# [OK] VISASTEEL_full -> VISASTEEL.NS (VISA Steel Limited)
# [OK] VLEGOV_full -> VLEGOV.NS (VL E-Governance & IT Solutions Limited)
# [OK] VLSFINANCE_full -> VLSFINANCE.NS (VLS Finance Limited)
# [OK] VIPCLOTHNG_full -> VIPCLOTHNG.NS (VIP Clothing Limited)
# [OK] VMART_full -> VMART.NS (V-Mart Retail Limited)
# [OK] VOLTAMP_full -> VOLTAMP.NS (Voltamp Transformers Limited)
# [OK] VIRINCHI_full -> VIRINCHI.NS (Virinchi Limited)
# [OK] VOLTAS_full -> VOLTAS.NS (Voltas Limited)
# [OK] VMM_full -> VMM.NS (VISHAL MEGA MART LIMITED)
# [OK] VRLLOG_full -> VRLLOG.NS (VRL Logistics Limited)
# [OK] VRAJ_full -> VRAJ.NS (VRAJ IRON AND STEEL LTD)
# [OK] VSTIND_full -> VSTIND.NS (VST Industries Limited)
# [OK] VSSL_full -> VSSL.NS (Vardhman Special Steels Limited)
# [OK] VTL_full -> VTL.NS (Vardhman Textiles Limited)
# [OK] VSTTILLERS_full -> VSTTILLERS.NS (V.S.T. Tillers Tractors Limited)
# [OK] VSTL_full -> VSTL.NS (Vibhor Steel Tubes Limited)
# [OK] VPRPL_full -> VPRPL.NS (Vishnu Prakash R Punglia Limited)
# [OK] WAAREEENER_full -> WAAREEENER.NS (WAAREE ENERGIES LIMITED)
# [OK] WAAREERTL_full -> WAAREERTL.NS (Waaree Renewable Technologies Limited)
# [OK] WABAG_full -> WABAG.NS (VA Tech Wabag Limited)
# [OK] WEALTH_full -> WEALTH.NS (Wealth First Portfolio Managers Limited)
# [OK] WALCHANNAG_full -> WALCHANNAG.NS (Walchandnagar Industries Limited)
# [OK] WCIL_full -> WCIL.NS (WESTERN CARRIERS (IND) L)
# [OK] WELCORP_full -> WELCORP.NS (Welspun Corp Limited)
# [OK] WANBURY_full -> WANBURY.NS (Wanbury Limited)
# [OK] WEBELSOLAR_full -> WEBELSOLAR.NS (Websol Energy System Limited)
# [OK] WEIZMANIND_full -> WEIZMANIND.NS (Weizmann Limited)
# [OK] WELSPUNLIV_full -> WELSPUNLIV.NS (Welspun Living Limited)
# [OK] WELENT_full -> WELENT.NS (Welspun Enterprises Limited)
# [OK] WEL_full -> WEL.NS (Wonder Electricals Limited)
# [OK] WESTLIFE_full -> WESTLIFE.NS (Westlife Foodworld Limited)
# [OK] WEWIN_full -> WEWIN.NS (We Win Limited)
# [OK] WHEELS_full -> WHEELS.NS (Wheels India Limited)
# [OK] WENDT_full -> WENDT.NS (Wendt (India) Limited)
# [OK] WELINV_full -> WELINV.NS (Welspun Investments and Commercials Limited)
# [OK] WINDLAS_full -> WINDLAS.NS (Windlas Biotech Limited)
# [OK] WHIRLPOOL_full -> WHIRLPOOL.NS (Whirlpool of India Limited)
# [OK] WINDMACHIN_full -> WINDMACHIN.NS (Windsor Machines Limited)
# [OK] WILLAMAGOR_full -> WILLAMAGOR.NS (Williamson Magor & Co. Limited)
# [OK] WIPL_full -> WIPL.NS (The Western India Plywoods Limited)
# [OK] WINSOME_full -> WINSOME.NS (Winsome Yarns Limited)
# [OK] WONDERLA_full -> WONDERLA.NS (Wonderla Holidays Limited)
# [OK] WOCKPHARMA_full -> WOCKPHARMA.NS (Wockhardt Limited)
# [OK] WIPRO_full -> WIPRO.NS (Wipro Limited)
# [OK] WSI_full -> WSI.NS (W.S. Industries (India) Limited)
# [OK] XCHANGING_full -> XCHANGING.NS (Xchanging Solutions Limited)
# [OK] WORTH_full -> WORTH.NS (Worth Peripherals Limited)
# [OK] XPROINDIA_full -> XPROINDIA.NS (Xpro India Limited)
# [OK] XELPMOC_full -> XELPMOC.NS (Xelpmoc Design and Tech Limited)
# [OK] WSTCSTPAPR_full -> WSTCSTPAPR.NS (West Coast Paper Mills Limited)
# [OK] XTGLOBAL_full -> XTGLOBAL.NS (XTGlobal Infotech Limited)
# [OK] YATHARTH_full -> YATHARTH.NS (Yatharth Hospital & Trauma Care Services Limited)
# [OK] YASHO_full -> YASHO.NS (Yasho Industries Limited)
# [OK] ZAGGLE_full -> ZAGGLE.NS (Zaggle Prepaid Ocean Services Limited)
# [OK] YATRA_full -> YATRA.NS (Yatra Online Limited)
# [OK] YAARI_full -> YAARI.NS (Yaari Digital Integrated Services Limited)
# [OK] ZEELEARN_full -> ZEELEARN.NS (Zee Learn Limited)
# [OK] YESBANK_full -> YESBANK.NS (Yes Bank Limited)
# [OK] YUKEN_full -> YUKEN.NS (Yuken India Limited)
# [OK] ZEEL_full -> ZEEL.NS (Zee Entertainment Enterprises Limited)
# [OK] ZENITHSTL_full -> ZENITHSTL.NS (Zenith Steel Pipes & Industries Limited)
# [OK] ZEEMEDIA_full -> ZEEMEDIA.NS (Zee Media Corporation Limited)
# [OK] ZFCVINDIA_full -> ZFCVINDIA.NS (ZF Commercial Vehicle Control Systems India Limited)
# [OK] ZENSARTECH_full -> ZENSARTECH.NS (Zensar Technologies Limited)
# [OK] ZENITHEXPO_full -> ZENITHEXPO.NS (Zenith Exports Limited)
# [OK] ZIMLAB_full -> ZIMLAB.NS (ZIM Laboratories Limited)
# [OK] ZENTEC_full -> ZENTEC.NS (Zen Technologies Limited)
# [OK] ZUARIIND_full -> ZUARIIND.NS (Zuari Industries Limited)
# [OK] ZODIACLOTH_full -> ZODIACLOTH.NS (Zodiac Clothing Company Limited)
# [OK] ZODIAC_full -> ZODIAC.NS (Zodiac Energy Limited)
# [OK] ZOTA_full -> ZOTA.NS (Zota Health Care Limited)
# [OK] ZUARI_full -> ZUARI.NS (Zuari Agro Chemicals Limited)
# [OK] ZYDUSWELL_full -> ZYDUSWELL.NS (Zydus Wellness Limited)
# [OK] ZYDUSLIFE_full -> ZYDUSLIFE.NS (Zydus Lifesciences Limited)
# Processing finished. Success: 2060, Failures: 75

# %%
# Cell 7 — Save Balance sheets workbook (one sheet per company)
print("Saving balances workbook:", OUT_BALANCE_XLSX)
with pd.ExcelWriter(OUT_BALANCE_XLSX, engine="openpyxl") as writer:
    for sheet_label, (symbol, company_name, bal_df) in balances_map.items():
        if bal_df is None or bal_df.empty:
            # put a small note sheet
            pd.DataFrame({"Note":[f"No balance sheet scraped for {symbol} ({company_name})"]}).to_excel(writer, sheet_name=sheet_label[:31], index=False)
        else:
            # ensure Unnamed: 0 exists for years/periods (match your old file layout)
            if "Unnamed: 0" not in bal_df.columns and bal_df.shape[1] > 0:
                # try to rename first col if it's index-like
                bal_df = bal_df.reset_index().rename(columns={"index":"Unnamed: 0"})
            bal_df.to_excel(writer, sheet_name=sheet_label[:31], index=False)
print("Balances saved.")
# Out:
# Saving balances workbook: C:\Users\KIIT\Downloads\all_companies_balancesheet.xlsx
# Balances saved.

# %%
# Cell 8 — Save Overview (single sheet)
print("Saving overview workbook:", OUT_OVERVIEW_XLSX)
df_overview = pd.DataFrame(overview_rows)
# Ensure all expected columns exist
for c in OVERVIEW_COLUMNS:
    if c not in df_overview.columns:
        df_overview[c] = None
df_overview = df_overview.reindex(columns=OVERVIEW_COLUMNS)
df_overview.to_excel(OUT_OVERVIEW_XLSX, index=False)
print("Overview saved.")
# Out:
# Saving overview workbook: C:\Users\KIIT\Downloads\all_companies_overview.xlsx
# Overview saved.

# %%
# Cell 9 — Save errors & manual mapping suggestions
print("Saving errors to:", ERRORS_CSV)
pd.DataFrame(errors, columns=["raw_input", "error"]).to_csv(ERRORS_CSV, index=False)

# For manual mapping suggestions, attempt quick suggestions using yahoo_search
manual_suggestions = []
for raw, _ in errors:
    suggs = yahoo_search(raw)
    # flatten top 5 symbols
    top_syms = [s.get("symbol") for s in suggs[:5]]
    manual_suggestions.append({"raw_input": raw, "suggestions": ",".join([str(x) for x in top_syms])})

pd.DataFrame(manual_suggestions).to_csv(MANUAL_MAP_CSV, index=False)
print("Errors and manual mapping suggestions saved.")
# Out:
# Saving errors to: C:\Users\KIIT\Downloads\errors.csv
# Errors and manual mapping suggestions saved.
